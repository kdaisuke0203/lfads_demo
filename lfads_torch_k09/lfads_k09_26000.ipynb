# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
np = torch._np
import matplotlib.pyplot as plt

import os
import yaml
import math
from lfads_k09 import LFADS_Net
from utils import read_data, load_parameters, save_parameters
import scipy.io
# plt.style.use('dark_background')
import shutil
path = './models_k09'
if os.path.isdir(path): 
    shutil.rmtree(path)

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load or Generate Data

# %%
all_time =35000
start_time = 0
Time = 30
neuron_num = 83
datax = scipy.io.loadmat("spike83_k09_35000.mat")
y_data = datax["spike83_k09_35000"][:,start_time:all_time].T
traj = scipy.io.loadmat("trj83_k09_35000.mat")
traj = traj["trj83_k09_35000"][:,start_time:all_time].T
NRep=int((all_time-start_time)/Time)
output = np.zeros((NRep,Time,neuron_num))
print(y_data.shape)
#for i in range(all_time-start_time):
#    for j in range(neuron_num):
#        if y_data[i][j] > 20:
#            y_data[i][j] = 20
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
output = output.astype('float32')
output = torch.Tensor(output).to(device)
print(output.shape)
output_valid = output.detach().clone()
# Out:
# (2000, 83)
# torch.Size([100, 20, 83])

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
train_ds      = torch.utils.data.TensorDataset(output)
valid_ds      = torch.utils.data.TensorDataset(output)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
plt.figure(figsize = (12,12))
plt.imshow(y_data.T, cmap=plt.cm.plasma,aspect='auto')
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
# Out:
# (20, 83)

# %%
#for i in range(neuron_num):
    #fig, ax = plt.subplots()
    #mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=8)
    #fig.colorbar(mappable)
    #plt.title(i)
    #plt.show()
#fig.savefig("img.png")

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters_k09.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# {'dataset_name': 'chaotic_rnn',
#  'run_name': 'demo',
#  'g_dim': 30,
#  'u_dim': 30,
#  'factors_dim': 2,
#  'g0_encoder_dim': 30,
#  'c_encoder_dim': 30,
#  'controller_dim': 30,
#  'g0_prior_kappa': 0.1,
#  'u_prior_kappa': 0.1,
#  'keep_prob': 0.95,
#  'clip_val': 5.0,
#  'max_norm': 200,
#  'learning_rate': 0.01,
#  'learning_rate_min': 1e-05,
#  'learning_rate_decay': 0.9,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'scheduler_cooldown': 6,
#  'kl_weight_schedule_start': 0,
#  'kl_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'l2_weight_schedule_dur': 2000,
#  'epsilon': 0.1,
#  'betas': (0.9, 0.99),
#  'l2_gen_scale': 2000,
#  'l2_con_scale': 0}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = neuron_num, T = Time, dt = 1, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 185

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')
batch_size = 2
"""tt = np.empty((3000,2))
for k in range(10):
    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t[90].shape)
    for i in range(batch_size):
        for j in range(100):
            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)"""
# Out:
# "tt = np.empty((3000,2))\nfor k in range(10):\n    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])\n    #print(t[90].shape)\n    for i in range(batch_size):\n        for j in range(100):\n            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()\nplt.figure()\nplt.plot(tt)"

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=2000, batch_size=batch_size , use_tensorboard=False,
          train_truth=train_ds, valid_truth=valid_ds)
# Out:
# Beginning training...
# Epoch:    1, Step:    50, training loss: 1840.697
# recon: 1318, kl:     9, dir: 5506, klf:    1, klw:    0
# Epoch:    2, Step:   100, training loss: 1731.512
# recon: 2284, kl:     4, dir: 43708, klf:    2, klw:    0
# Epoch:    3, Step:   150, training loss: 1721.656
# recon: 1413, kl:     3, dir: 8035, klf:    1, klw:    0
# Epoch:    4, Step:   200, training loss: 1687.450
# recon: 1689, kl:     8, dir: 9271, klf:    3, klw:    0
# Epoch:    5, Step:   250, training loss: 1610.193
# recon: 1831, kl:    11, dir: 6874, klf:    4, klw:    0
# Epoch:    6, Step:   300, training loss: 1577.929
# recon: 1695, kl:    17, dir: 3559, klf:    5, klw:    0
# Epoch:    7, Step:   350, training loss: 1563.312
# recon: 1915, kl:    12, dir: 13545, klf:    8, klw:    0
# Epoch:    8, Step:   400, training loss: 1549.441
# recon: 2168, kl:    18, dir: 15102, klf:   10, klw:    0
# Epoch:    9, Step:   450, training loss: 1531.963
# recon: 1670, kl:    23, dir: 6353, klf:   11, klw:    0
# Epoch:   10, Step:   500, training loss: 1513.801
# recon: 1155, kl:    21, dir: 1740, klf:    9, klw:    0
# Epoch:   11, Step:   550, training loss: 1521.931
# recon: 1353, kl:    19, dir: 4881, klf:    9, klw:    0
# Epoch:   12, Step:   600, training loss: 1501.087
# recon: 1292, kl:    19, dir: 9060, klf:   11, klw:    0
# Epoch:   13, Step:   650, training loss: 1492.626
# recon: 1533, kl:    32, dir: 3640, klf:   12, klw:    0
# Epoch:   14, Step:   700, training loss: 1481.240
# recon: 1418, kl:    30, dir: 4218, klf:   14, klw:    0
# Epoch:   15, Step:   750, training loss: 1481.903
# recon: 1394, kl:    28, dir: 23254, klf:   13, klw:    0
# Epoch:   16, Step:   800, training loss: 1480.196
# recon: 1484, kl:    25, dir: 3296, klf:   15, klw:    0
# Epoch:   17, Step:   850, training loss: 1480.786
# recon: 1082, kl:    27, dir: 1369, klf:    9, klw:    0
# Epoch:   18, Step:   900, training loss: 1470.645
# recon: 1158, kl:    33, dir: 2333, klf:   19, klw:    0
# Epoch:   19, Step:   950, training loss: 1477.775
# recon: 1362, kl:    23, dir: 4603, klf:   14, klw:    0
# Epoch:   20, Step:  1000, training loss: 1469.458
# recon: 1451, kl:    33, dir: 1648, klf:   19, klw:    0
# Epoch:   21, Step:  1050, training loss: 1473.962
# recon: 1978, kl:    28, dir: 10406, klf:   17, klw:    0
# Epoch:   22, Step:  1100, training loss: 1476.879
# recon: 1131, kl:    24, dir: 3094, klf:   13, klw:    0
# Epoch:   23, Step:  1150, training loss: 1466.170
# recon: 1449, kl:    28, dir: 6734, klf:   17, klw:    0
# Epoch:   24, Step:  1200, training loss: 1466.408
# recon: 1742, kl:    40, dir: 38968, klf:   21, klw:    0
# Epoch:   25, Step:  1250, training loss: 1467.840
# recon: 1496, kl:    35, dir: 3194, klf:   21, klw:    0
# Epoch:   26, Step:  1300, training loss: 1469.718
# recon:  828, kl:    23, dir: 4592, klf:   18, klw:    0
# Epoch:   27, Step:  1350, training loss: 1477.689
# recon: 1196, kl:    29, dir: 2201, klf:   13, klw:    0
# Learning rate decreased to 0.00900000
# Epoch:   28, Step:  1400, training loss: 1477.444
# recon: 1538, kl:    42, dir: 4401, klf:   17, klw:    0
# Epoch:   29, Step:  1450, training loss: 1470.422
# recon: 1016, kl:    27, dir: 1106, klf:   20, klw:    0
# Epoch:   30, Step:  1500, training loss: 1465.815
# recon: 1256, kl:    33, dir: 1224, klf:   18, klw:    0
# Epoch:   31, Step:  1550, training loss: 1472.168
# recon: 1571, kl:    39, dir: 3238, klf:   21, klw:    0
# Epoch:   32, Step:  1600, training loss: 1463.517
# recon: 1602, kl:    42, dir: 6040, klf:   25, klw:    0
# Epoch:   33, Step:  1650, training loss: 1463.569
# recon: 1682, kl:    34, dir: 5249, klf:   17, klw:    0
# Epoch:   34, Step:  1700, training loss: 1465.905
# recon: 1929, kl:    48, dir: 5452, klf:   30, klw:    0
# Epoch:   35, Step:  1750, training loss: 1469.414
# recon: 1862, kl:    56, dir: 79252, klf:   33, klw:    0
# Epoch:   36, Step:  1800, training loss: 1476.658
# recon: 1687, kl:    41, dir: 2943, klf:   25, klw:    0
# Learning rate decreased to 0.00810000
# Epoch:   37, Step:  1850, training loss: 1470.811
# recon: 1342, kl:    32, dir: 2800, klf:   19, klw:    0
# Epoch:   38, Step:  1900, training loss: 1466.315
# recon: 1603, kl:    38, dir: 3381, klf:   24, klw:    0
# Epoch:   39, Step:  1950, training loss: 1462.197
# recon: 1575, kl:    51, dir: 4960, klf:   27, klw:    0
# Epoch:   40, Step:  2000, training loss: 1468.875
# recon:  916, kl:    28, dir:  579, klf:   14, klw:    1
# Epoch:   41, Step:  2050, training loss: 1458.117
# recon: 1524, kl:    44, dir: 2591, klf:   26, klw:    1
# Epoch:   42, Step:  2100, training loss: 1463.963
# recon: 1921, kl:    50, dir: 10373, klf:   31, klw:    1
# Epoch:   43, Step:  2150, training loss: 1463.236
# recon: 1653, kl:    46, dir: 8195, klf:   28, klw:    1
# Epoch:   44, Step:  2200, training loss: 1460.944
# recon: 1574, kl:    50, dir: 3939, klf:   29, klw:    1
# Epoch:   45, Step:  2250, training loss: 1459.268
# recon: 1074, kl:    29, dir: 1626, klf:   21, klw:    1
# Epoch:   46, Step:  2300, training loss: 1451.176
# recon: 1215, kl:    31, dir: 5452, klf:   23, klw:    1
# Epoch:   47, Step:  2350, training loss: 1455.202
# recon: 1462, kl:    45, dir: 6004, klf:   22, klw:    1
# Epoch:   48, Step:  2400, training loss: 1455.723
# recon: 1216, kl:    36, dir: 2434, klf:   24, klw:    1
# Epoch:   49, Step:  2450, training loss: 1451.657
# recon: 1354, kl:    38, dir: 1334, klf:   22, klw:    1
# Epoch:   50, Step:  2500, training loss: 1458.624
# recon: 1303, kl:    36, dir: 2430, klf:   21, klw:    1
# Epoch:   51, Step:  2550, training loss: 1463.087
# recon: 1698, kl:    38, dir: 9414, klf:   33, klw:    1
# Learning rate decreased to 0.00729000
# Epoch:   52, Step:  2600, training loss: 1453.581
# recon: 1656, kl:    69, dir: 7028, klf:   30, klw:    1
# Epoch:   53, Step:  2650, training loss: 1450.310
# recon: 1182, kl:    38, dir: 4676, klf:   28, klw:    1
# Epoch:   54, Step:  2700, training loss: 1458.437
# recon: 1848, kl:    53, dir: 3136, klf:   31, klw:    1
# Epoch:   55, Step:  2750, training loss: 1452.105
# recon: 1562, kl:    59, dir: 11634, klf:   27, klw:    1
# Epoch:   56, Step:  2800, training loss: 1442.929
# recon: 1620, kl:    54, dir: 5128, klf:   30, klw:    1
# Epoch:   57, Step:  2850, training loss: 1444.683
# recon: 1413, kl:    41, dir: 2575, klf:   23, klw:    1
# Epoch:   58, Step:  2900, training loss: 1440.902
# recon: 1156, kl:    39, dir: 2236, klf:   22, klw:    1
# Epoch:   59, Step:  2950, training loss: 1451.469
# recon: 1247, kl:    37, dir: 2190, klf:   18, klw:    1
# Epoch:   60, Step:  3000, training loss: 1446.137
# recon: 1939, kl:    40, dir: 4806, klf:   21, klw:    1
# Epoch:   61, Step:  3050, training loss: 1446.360
# recon: 1260, kl:    26, dir: 3180, klf:   17, klw:    1
# Epoch:   62, Step:  3100, training loss: 1440.608
# recon: 1677, kl:    34, dir: 2715, klf:   23, klw:    1
# Epoch:   63, Step:  3150, training loss: 1436.153
# recon: 1473, kl:    33, dir: 2835, klf:   25, klw:    1
# Epoch:   64, Step:  3200, training loss: 1451.029
# recon: 2009, kl:    53, dir: 8175, klf:   27, klw:    1
# Epoch:   65, Step:  3250, training loss: 1442.727
# recon: 1238, kl:    30, dir: 8242, klf:   14, klw:    1
# Epoch:   66, Step:  3300, training loss: 1448.283
# recon: 1416, kl:    43, dir: 2794, klf:   28, klw:    1
# Epoch:   67, Step:  3350, training loss: 1444.007
# recon: 1192, kl:    31, dir: 2662, klf:   16, klw:    1
# Epoch:   68, Step:  3400, training loss: 1431.377
# recon: 1282, kl:    35, dir: 2438, klf:   22, klw:    1
# Epoch:   69, Step:  3450, training loss: 1443.823
# recon: 1382, kl:    38, dir: 2225, klf:   21, klw:    1
# Epoch:   70, Step:  3500, training loss: 1438.758
# recon: 1273, kl:    48, dir: 3875, klf:   24, klw:    1
# Epoch:   71, Step:  3550, training loss: 1436.106
# recon: 1674, kl:    58, dir: 4000, klf:   38, klw:    1
# Epoch:   72, Step:  3600, training loss: 1431.605
# recon: 1568, kl:    45, dir: 5077, klf:   22, klw:    1
# Epoch:   73, Step:  3650, training loss: 1431.871
# recon: 1098, kl:    28, dir: 4964, klf:   18, klw:    1
# Epoch:   74, Step:  3700, training loss: 1435.573
# recon: 1397, kl:    42, dir: 3943, klf:   18, klw:    1
# Epoch:   75, Step:  3750, training loss: 1431.363
# recon: 1059, kl:    21, dir: 7086, klf:   14, klw:    1
# Epoch:   76, Step:  3800, training loss: 1432.220
# recon: 1133, kl:    25, dir: 2195, klf:   24, klw:    1

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
print(output_valid.shape)
#model.plot_factors()
tt = np.zeros(((all_time-start_time),2))
sp = np.zeros(((all_time-start_time),neuron_num))
batch_size=1
gg = int(NRep/batch_size)
import math
def mutual_info(m):
    K=30
    h_y_xw = np.zeros(neuron_num)
    h_y_x = np.zeros(neuron_num)
    T = m.shape[0]
    for n in range(neuron_num):
        for k in range(K):
            h_y_xw_tem = 0
            h_y_x_tem = 0
            for t in range(T):
                h_y_xw_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)) * np.log(m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)))
                h_y_x_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k))
            h_y_xw[n] += h_y_xw_tem/T
            h_y_x[n] -= h_y_x_tem/T * math.log(h_y_x_tem/T)
            
    return  h_y_xw.sum(), h_y_x.sum()

for k in range(gg):
    t = model.infer_factors(output_valid[batch_size *k:batch_size *(k+1),:])
    #spi = model.reconstruct(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(spi.shape)
    for i in range(batch_size):
        for j in range(Time):
            tt[(i+batch_size*k)*Time+j,:] = t[i][j].to('cpu').detach().numpy().copy()
            #print(model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10))
            #y_hat = model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10)
            #print(mutual_info(y_hat))
            #obs_mc_mean = y_hat.mean(axis=0)
            #obs_mc_std = y_hat.std(axis=0)
            #print(poisson_entropy(np.round(obs_mc_mean)))
            #for l in range(neuron_num):
                #sp[(i+batch_size*k)*Time+j,l] = spi[j][l]
plt.figure()
plt.plot(tt)

# %%
next_state = model.transition_rnn(tt[:1,:])
print(next_state)

# %% [markdown]
# ## Plot results summary

# %%
# for i in range(neuron_num):
    plt.figure()
    plt.plot(y_data[:,i], linewidth = 2)
    plt.plot(sp[:,i],'r',linewidth = 1)
    plt.title(i)
    plt.ylim(-2,20)

# %%
import funs
from scipy import signal
qz_mean_est = tt
#plt.plot(qz_mean_est[:,1])
qz_est_norm = qz_mean_est#np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
qz_est_norm[:,0] = signal.savgol_filter(qz_est_norm[:,0], 51, 5)
qz_est_norm[:,1] = signal.savgol_filter(qz_est_norm[:,1],51, 5)
plt.plot(qz_est_norm[:,0],qz_est_norm[:,1])
z_true_c = traj# - x_test.mean(axis=0)
z_true_norm = z_true_c#/np.linalg.norm(z_true_c)

R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
st=0
en=3000
plt.figure(figsize=(14,8))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[st:en,0],'r', linewidth = 1, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[st:en,0], 'k', linewidth = 1, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[st:en,1],'r', linewidth = 1, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[st:en,1], 'k', linewidth = 1, label = '\"true\" mean')

fig = plt.figure(figsize=(5,5))
plt.plot(z_true_norm[st:en,0], z_true_norm[st:en,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[st:en,0], qz_est_norm_R[st:en,1], lw=2, color = 'r')

# %%
#np.savetxt('lfads_k09_sim_12301628.csv', qz_est_norm_R, delimiter=',')
