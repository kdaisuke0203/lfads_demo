# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
np = torch._np
import matplotlib.pyplot as plt

import os
import yaml
import math
from lfads_sim import LFADS_Net
from utils import read_data, load_parameters, save_parameters
import scipy.io
# plt.style.use('dark_background')
import shutil
path = './models_sim'
if os.path.isdir(path): 
    shutil.rmtree(path)

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load or Generate Data

# %%
all_time =2500
start_time = 0
Time = 20
neuron_num = 30
datax = scipy.io.loadmat("spike30_sim_3000.mat")
y_data = datax["spike30_sim_3000"][start_time:all_time,:]
traj = scipy.io.loadmat("trj30_sim_3000.mat")
traj = traj["trj30_sim_3000"][start_time:all_time,:]
NRep=int((all_time-start_time)/Time)
output = np.zeros((NRep,Time,neuron_num))
print(y_data.shape)
#for i in range(all_time-start_time):
#    for j in range(neuron_num):
#        if y_data[i][j] > 20:
#            y_data[i][j] = 20
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
output = output.astype('float32')
output = torch.Tensor(output).to(device)
print(output.shape)
output_valid = output.detach().clone()
# Out:
# (2500, 30)
# torch.Size([125, 20, 30])

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
train_ds      = torch.utils.data.TensorDataset(output)
valid_ds      = torch.utils.data.TensorDataset(output)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
plt.figure(figsize = (12,12))
plt.imshow(y_data.T, cmap=plt.cm.plasma,aspect='auto')
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
# Out:
# (20, 30)

# %%
#for i in range(neuron_num):
    #fig, ax = plt.subplots()
    #mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=8)
    #fig.colorbar(mappable)
    #plt.title(i)
    #plt.show()
#fig.savefig("img.png")

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters_sim.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# {'dataset_name': 'chaotic_rnn',
#  'run_name': 'demo',
#  'g_dim': 30,
#  'u_dim': 30,
#  'factors_dim': 2,
#  'g0_encoder_dim': 30,
#  'c_encoder_dim': 30,
#  'controller_dim': 30,
#  'g0_prior_kappa': 0.1,
#  'u_prior_kappa': 0.1,
#  'keep_prob': 0.95,
#  'clip_val': 5.0,
#  'max_norm': 200,
#  'learning_rate': 0.01,
#  'learning_rate_min': 1e-05,
#  'learning_rate_decay': 0.9,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'scheduler_cooldown': 6,
#  'kl_weight_schedule_start': 0,
#  'kl_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'l2_weight_schedule_dur': 2000,
#  'epsilon': 0.1,
#  'betas': (0.9, 0.99),
#  'l2_gen_scale': 2000,
#  'l2_con_scale': 0}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = neuron_num, T = Time, dt = 1, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 5904

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')
batch_size = 2
"""tt = np.empty((3000,2))
for k in range(10):
    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t[90].shape)
    for i in range(batch_size):
        for j in range(100):
            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)"""
# Out:
# "tt = np.empty((3000,2))\nfor k in range(10):\n    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])\n    #print(t[90].shape)\n    for i in range(batch_size):\n        for j in range(100):\n            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()\nplt.figure()\nplt.plot(tt)"

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=200, batch_size=batch_size , use_tensorboard=False,
          train_truth=train_ds, valid_truth=valid_ds)
# Out:
# Beginning training...
# Epoch:    1, Step:    63, training loss: 541.029
# recon:  568, kl:    15, dir:  358, klf:    2, klw:    0
# Epoch:    2, Step:   126, training loss: 394.747
# recon:  370, kl:    25, dir: 10527, klf:    3, klw:    0
# Epoch:    3, Step:   189, training loss: 340.362
# recon:  333, kl:    10, dir: 1939, klf:    4, klw:    0
# Epoch:    4, Step:   252, training loss: 343.720
# recon:  605, kl:    20, dir: 1094, klf:    6, klw:    0
# Epoch:    5, Step:   315, training loss: 342.759
# recon:  291, kl:    15, dir:    4, klf:    5, klw:    0
# Epoch:    6, Step:   378, training loss: 314.270
# recon:  414, kl:    18, dir: 1749, klf:    6, klw:    0
# Epoch:    7, Step:   441, training loss: 300.196
# recon:   97, kl:    12, dir:    0, klf:    5, klw:    0
# Epoch:    8, Step:   504, training loss: 310.455
# recon:  321, kl:    37, dir:  527, klf:   11, klw:    0
# Epoch:    9, Step:   567, training loss: 304.261
# recon:  332, kl:    24, dir:  405, klf:   10, klw:    0
# Epoch:   10, Step:   630, training loss: 295.536
# recon:  228, kl:    16, dir:  212, klf:    6, klw:    0
# Epoch:   11, Step:   693, training loss: 286.166
# recon:   95, kl:    10, dir:  129, klf:    7, klw:    0
# Epoch:   12, Step:   756, training loss: 294.666
# recon:  325, kl:    63, dir:  225, klf:   14, klw:    0
# Epoch:   13, Step:   819, training loss: 305.407
# recon:  204, kl:    25, dir:  144, klf:    9, klw:    0
# Epoch:   14, Step:   882, training loss: 293.058
# recon:  477, kl:    23, dir: 3634, klf:    7, klw:    0
# Epoch:   15, Step:   945, training loss: 285.066
# recon:  197, kl:    16, dir:  266, klf:    3, klw:    0
# Epoch:   16, Step:  1008, training loss: 290.479
# recon:  339, kl:    40, dir:  604, klf:   16, klw:    0
# Epoch:   17, Step:  1071, training loss: 294.100
# recon:  342, kl:    17, dir:  502, klf:    6, klw:    0
# Epoch:   18, Step:  1134, training loss: 296.688
# recon:  310, kl:    57, dir:  966, klf:   15, klw:    0
# Epoch:   19, Step:  1197, training loss: 317.507
# recon: 1046, kl:    58, dir:  544, klf:   18, klw:    0
# Learning rate decreased to 0.00900000
# Epoch:   20, Step:  1260, training loss: 281.613
# recon:  102, kl:    15, dir:   72, klf:   12, klw:    0
# Epoch:   21, Step:  1323, training loss: 277.972
# recon:  274, kl:     9, dir: 2732, klf:    8, klw:    0
# Epoch:   22, Step:  1386, training loss: 295.511
# recon:  773, kl:    73, dir:   86, klf:   23, klw:    0
# Epoch:   23, Step:  1449, training loss: 297.875
# recon:   79, kl:    17, dir:    0, klf:    8, klw:    0
# Epoch:   24, Step:  1512, training loss: 290.556
# recon:   99, kl:    17, dir:   43, klf:   10, klw:    0
# Epoch:   25, Step:  1575, training loss: 295.870
# recon:  267, kl:    15, dir: 1130, klf:    7, klw:    0
# Epoch:   26, Step:  1638, training loss: 296.791
# recon:  103, kl:    16, dir:   55, klf:   13, klw:    0
# Epoch:   27, Step:  1701, training loss: 294.818
# recon:  105, kl:    12, dir:    3, klf:    7, klw:    0
# Epoch:   28, Step:  1764, training loss: 303.987
# recon:  115, kl:    12, dir:    7, klf:    9, klw:    0
# Learning rate decreased to 0.00810000
# Epoch:   29, Step:  1827, training loss: 295.650
# recon:  737, kl:    74, dir:  553, klf:   21, klw:    0
# Epoch:   30, Step:  1890, training loss: 293.351
# recon:  210, kl:    15, dir:  641, klf:    6, klw:    0
# Epoch:   31, Step:  1953, training loss: 294.163
# recon:  102, kl:    16, dir:    0, klf:   16, klw:    0
# Epoch:   32, Step:  2016, training loss: 281.219
# recon:  195, kl:    15, dir:  547, klf:    5, klw:    1
# Epoch:   33, Step:  2079, training loss: 283.102
# recon:  272, kl:    52, dir:  503, klf:   24, klw:    1
# Epoch:   34, Step:  2142, training loss: 283.666
# recon:  213, kl:    13, dir:  499, klf:    5, klw:    1
# Epoch:   35, Step:  2205, training loss: 285.079
# recon:  284, kl:    30, dir:  794, klf:   19, klw:    1
# Epoch:   36, Step:  2268, training loss: 297.483
# recon:  528, kl:    52, dir:  151, klf:   17, klw:    1
# Learning rate decreased to 0.00729000
# Epoch:   37, Step:  2331, training loss: 301.620
# recon:  753, kl:    63, dir: 4798, klf:   18, klw:    1
# Epoch:   38, Step:  2394, training loss: 285.104
# recon:  221, kl:     8, dir:  356, klf:    8, klw:    1
# Epoch:   39, Step:  2457, training loss: 279.063
# recon:  229, kl:    32, dir:  178, klf:   22, klw:    1
# Epoch:   40, Step:  2520, training loss: 283.526
# recon:  132, kl:    15, dir:    7, klf:    7, klw:    1
# Epoch:   41, Step:  2583, training loss: 285.321
# recon:  208, kl:     6, dir:  336, klf:    7, klw:    1
# Epoch:   42, Step:  2646, training loss: 284.889
# recon:  204, kl:    14, dir: 1506, klf:    3, klw:    1
# Epoch:   43, Step:  2709, training loss: 279.701
# recon:  215, kl:    45, dir:  289, klf:   15, klw:    1
# Epoch:   44, Step:  2772, training loss: 274.647
# recon:  280, kl:    11, dir:  569, klf:    4, klw:    1
# Epoch:   45, Step:  2835, training loss: 269.248
# recon:  271, kl:    10, dir: 1433, klf:    4, klw:    1
# Epoch:   46, Step:  2898, training loss: 270.432
# recon:  220, kl:    24, dir:  212, klf:   12, klw:    1
# Epoch:   47, Step:  2961, training loss: 284.826
# recon:  215, kl:     7, dir:  398, klf:    6, klw:    1
# Epoch:   48, Step:  3024, training loss: 279.631
# recon:  235, kl:    38, dir:  337, klf:   14, klw:    1
# Epoch:   49, Step:  3087, training loss: 288.084
# recon:  177, kl:    20, dir:  292, klf:   12, klw:    1
# Learning rate decreased to 0.00656100
# Epoch:   50, Step:  3150, training loss: 270.927
# recon:  410, kl:    38, dir:  370, klf:   18, klw:    1
# Epoch:   51, Step:  3213, training loss: 273.828
# recon:  264, kl:    52, dir:  742, klf:   35, klw:    1
# Epoch:   52, Step:  3276, training loss: 258.047
# recon:  215, kl:     8, dir:  430, klf:    5, klw:    1
# Epoch:   53, Step:  3339, training loss: 273.976
# recon:  210, kl:    29, dir:  432, klf:   19, klw:    1
# Epoch:   54, Step:  3402, training loss: 267.312
# recon:  208, kl:     6, dir:  293, klf:    2, klw:    1
# Epoch:   55, Step:  3465, training loss: 265.395
# recon:  180, kl:    14, dir:  484, klf:   14, klw:    1
# Epoch:   56, Step:  3528, training loss: 270.660
# recon:  204, kl:     6, dir:  472, klf:    3, klw:    1
# Epoch:   57, Step:  3591, training loss: 267.299
# recon:  432, kl:    48, dir: 1141, klf:   16, klw:    1
# Epoch:   58, Step:  3654, training loss: 266.807
# recon:  256, kl:     6, dir:  863, klf:    5, klw:    1
# Epoch:   59, Step:  3717, training loss: 262.798
# recon:  199, kl:     6, dir:  282, klf:    3, klw:    1
# Epoch:   60, Step:  3780, training loss: 269.857
# recon:  202, kl:    27, dir:  291, klf:   17, klw:    1
# Epoch:   61, Step:  3843, training loss: 270.578
# recon:  171, kl:    25, dir:  604, klf:   25, klw:    1
# Epoch:   62, Step:  3906, training loss: 271.771
# recon:  224, kl:     8, dir:  406, klf:    5, klw:    1
# Learning rate decreased to 0.00590490
# Epoch:   63, Step:  3969, training loss: 264.142
# recon:  243, kl:    30, dir:  352, klf:   17, klw:    1
# Epoch:   64, Step:  4032, training loss: 254.744
# recon:   74, kl:    10, dir:    0, klf:    7, klw:    1
# Epoch:   65, Step:  4095, training loss: 261.034
# recon:   74, kl:    10, dir:    0, klf:    5, klw:    1
# Epoch:   66, Step:  4158, training loss: 264.816
# recon:  205, kl:    13, dir:  389, klf:   11, klw:    1
# Epoch:   67, Step:  4221, training loss: 254.404
# recon:  116, kl:    11, dir:   45, klf:    9, klw:    1
# Epoch:   68, Step:  4284, training loss: 265.705
# recon:  219, kl:     4, dir:  437, klf:    2, klw:    1
# Epoch:   69, Step:  4347, training loss: 260.201
# recon:  235, kl:    57, dir: 11718, klf:   34, klw:    1
# Epoch:   70, Step:  4410, training loss: 260.188
# recon:  145, kl:    12, dir:    4, klf:    6, klw:    1
# Epoch:   71, Step:  4473, training loss: 261.696
# recon:  391, kl:     5, dir:  558, klf:    5, klw:    1
# Epoch:   72, Step:  4536, training loss: 259.751
# recon:  192, kl:    10, dir:  553, klf:    9, klw:    1
# Epoch:   73, Step:  4599, training loss: 260.752
# recon:  108, kl:     9, dir:   14, klf:    8, klw:    1
# Epoch:   74, Step:  4662, training loss: 295.477
# recon:  248, kl:    16, dir:  409, klf:   11, klw:    1
# Learning rate decreased to 0.00531441
# Epoch:   75, Step:  4725, training loss: 266.317
# recon:  240, kl:     6, dir:  515, klf:    4, klw:    1
# Epoch:   76, Step:  4788, training loss: 259.405
# recon:  199, kl:    28, dir:  384, klf:   11, klw:    1
# Epoch:   77, Step:  4851, training loss: 264.459
# recon:  194, kl:     9, dir:  159, klf:    6, klw:    1
# Epoch:   78, Step:  4914, training loss: 251.935
# recon:  235, kl:     5, dir:  561, klf:    4, klw:    1
# Epoch:   79, Step:  4977, training loss: 250.885
# recon:  213, kl:     8, dir:  358, klf:    5, klw:    1
# Epoch:   80, Step:  5040, training loss: 249.000
# recon:  192, kl:    32, dir: 4799, klf:   17, klw:    1
# Epoch:   81, Step:  5103, training loss: 257.402
# recon:  217, kl:    19, dir:  939, klf:   11, klw:    1
# Epoch:   82, Step:  5166, training loss: 250.542
# recon:  124, kl:     6, dir:   34, klf:    6, klw:    1
# Epoch:   83, Step:  5229, training loss: 252.925
# recon:  405, kl:     6, dir: 1362, klf:    4, klw:    1
# Epoch:   84, Step:  5292, training loss: 261.403
# recon:  262, kl:     8, dir:  369, klf:    3, klw:    1
# Learning rate decreased to 0.00478297
# Epoch:   85, Step:  5355, training loss: 247.581
# recon:   87, kl:     8, dir:    4, klf:    5, klw:    1
# Epoch:   86, Step:  5418, training loss: 259.070
# recon:  195, kl:     8, dir:  398, klf:    2, klw:    1
# Epoch:   87, Step:  5481, training loss: 251.285
# recon:  255, kl:    35, dir:  502, klf:   20, klw:    1
# Epoch:   88, Step:  5544, training loss: 257.111
# recon:  186, kl:     8, dir:  305, klf:    6, klw:    1
# Epoch:   89, Step:  5607, training loss: 248.643
# recon:  210, kl:     5, dir:  229, klf:    2, klw:    1
# Epoch:   90, Step:  5670, training loss: 246.572
# recon:  102, kl:     5, dir:   99, klf:    5, klw:    1
# Epoch:   91, Step:  5733, training loss: 245.868
# recon:  220, kl:    11, dir:  301, klf:    8, klw:    1
# Epoch:   92, Step:  5796, training loss: 250.338
# recon:  322, kl:     5, dir:  282, klf:    1, klw:    1
# Epoch:   93, Step:  5859, training loss: 251.922
# recon:  273, kl:    47, dir: 2100, klf:   24, klw:    1
# Epoch:   94, Step:  5922, training loss: 252.905
# recon:  270, kl:    44, dir: 2085, klf:   17, klw:    1
# Epoch:   95, Step:  5985, training loss: 246.245
# recon:  201, kl:     5, dir:  266, klf:    3, klw:    1
# Epoch:   96, Step:  6048, training loss: 245.360
# recon:  121, kl:    16, dir:    0, klf:   11, klw:    1
# Epoch:   97, Step:  6111, training loss: 243.091
# recon:  239, kl:    30, dir:  368, klf:   13, klw:    1
# Epoch:   98, Step:  6174, training loss: 246.419
# recon:   98, kl:    11, dir:  148, klf:    9, klw:    1
# Epoch:   99, Step:  6237, training loss: 256.086
# recon:  205, kl:     6, dir:  571, klf:    3, klw:    1
# Learning rate decreased to 0.00430467
# Epoch:  100, Step:  6300, training loss: 250.381
# recon:  200, kl:    19, dir:  298, klf:   12, klw:    1
# Epoch:  101, Step:  6363, training loss: 243.970
# recon:  214, kl:    19, dir:  365, klf:   13, klw:    1
# Epoch:  102, Step:  6426, training loss: 246.536
# recon:  218, kl:    36, dir:  358, klf:   16, klw:    1
# Epoch:  103, Step:  6489, training loss: 241.316
# recon:  148, kl:    22, dir:  187, klf:   12, klw:    1
# Epoch:  104, Step:  6552, training loss: 242.748
# recon:  213, kl:     7, dir:  928, klf:    2, klw:    1
# Epoch:  105, Step:  6615, training loss: 246.237
# recon:  155, kl:    23, dir:  527, klf:   27, klw:    1
# Epoch:  106, Step:  6678, training loss: 241.717
# recon:   71, kl:     7, dir:   31, klf:   11, klw:    1
# Epoch:  107, Step:  6741, training loss: 244.168
# recon:  175, kl:    22, dir:  230, klf:   14, klw:    1
# Epoch:  108, Step:  6804, training loss: 245.282
# recon:  116, kl:     9, dir:    3, klf:    5, klw:    1
# Epoch:  109, Step:  6867, training loss: 243.532
# recon:  229, kl:    10, dir:  814, klf:    9, klw:    1
# Epoch:  110, Step:  6930, training loss: 250.897
# recon:  111, kl:     6, dir:   15, klf:    6, klw:    1
# Learning rate decreased to 0.00387420
# Epoch:  111, Step:  6993, training loss: 238.237
# recon:  138, kl:     8, dir:  193, klf:   12, klw:    1
# Epoch:  112, Step:  7056, training loss: 237.959
# recon:   77, kl:     5, dir:   53, klf:    5, klw:    1
# Epoch:  113, Step:  7119, training loss: 240.257
# recon:  186, kl:    22, dir:  163, klf:   11, klw:    1
# Epoch:  114, Step:  7182, training loss: 245.746
# recon:  200, kl:    33, dir:  172, klf:   16, klw:    1
# Epoch:  115, Step:  7245, training loss: 243.294
# recon:  217, kl:     4, dir:  455, klf:    3, klw:    1
# Epoch:  116, Step:  7308, training loss: 251.001
# recon:  334, kl:    10, dir:  502, klf:    4, klw:    1
# Learning rate decreased to 0.00348678
# Epoch:  117, Step:  7371, training loss: 248.694
# recon:  342, kl:    36, dir: 1226, klf:   14, klw:    1
# Epoch:  118, Step:  7434, training loss: 241.699
# recon:  211, kl:     3, dir:  519, klf:    2, klw:    1
# Epoch:  119, Step:  7497, training loss: 233.502
# recon:  208, kl:     4, dir:  440, klf:    3, klw:    1
# Epoch:  120, Step:  7560, training loss: 246.482
# recon:   90, kl:     8, dir:    4, klf:    3, klw:    1
# Epoch:  121, Step:  7623, training loss: 236.466
# recon:   98, kl:     4, dir:  768, klf:    4, klw:    1
# Epoch:  122, Step:  7686, training loss: 239.305
# recon:  216, kl:    31, dir:  264, klf:   16, klw:    1
# Epoch:  123, Step:  7749, training loss: 256.652
# recon:  207, kl:     3, dir:  335, klf:    2, klw:    1
# Learning rate decreased to 0.00313811
# Epoch:  124, Step:  7812, training loss: 243.394
# recon:  194, kl:    11, dir:  418, klf:    5, klw:    1
# Epoch:  125, Step:  7875, training loss: 244.000
# recon:  201, kl:    15, dir:  469, klf:   16, klw:    1
# Epoch:  126, Step:  7938, training loss: 244.658
# recon:  284, kl:    31, dir:  265, klf:   21, klw:    1
# Epoch:  127, Step:  8001, training loss: 237.549
# recon:   62, kl:     4, dir:   86, klf:    3, klw:    1
# Epoch:  128, Step:  8064, training loss: 237.909
# recon:  278, kl:    35, dir:  960, klf:   25, klw:    1
# Epoch:  129, Step:  8127, training loss: 245.969
# recon:  254, kl:    25, dir:  574, klf:   18, klw:    1
# Epoch:  130, Step:  8190, training loss: 241.329
# recon:  188, kl:     5, dir:  550, klf:    5, klw:    1
# Epoch:  131, Step:  8253, training loss: 237.937
# recon:  273, kl:    16, dir:  582, klf:    2, klw:    1
# Epoch:  132, Step:  8316, training loss: 238.295
# recon:   69, kl:     6, dir:  123, klf:    6, klw:    1
# Epoch:  133, Step:  8379, training loss: 239.152
# recon:  193, kl:    37, dir: 2379, klf:   23, klw:    1
# Epoch:  134, Step:  8442, training loss: 236.726
# recon:  193, kl:    25, dir:  447, klf:   20, klw:    1
# Epoch:  135, Step:  8505, training loss: 239.874
# recon:  270, kl:     7, dir:  514, klf:    4, klw:    1
# Epoch:  136, Step:  8568, training loss: 243.096
# recon:  199, kl:     5, dir:  560, klf:    2, klw:    1
# Learning rate decreased to 0.00282430
# Epoch:  137, Step:  8631, training loss: 236.584
# recon:  288, kl:    45, dir:  550, klf:   23, klw:    1
# Epoch:  138, Step:  8694, training loss: 234.514
# recon:  218, kl:     3, dir:  204, klf:    5, klw:    1
# Epoch:  139, Step:  8757, training loss: 234.189
# recon:   76, kl:     7, dir:    0, klf:    6, klw:    1
# Epoch:  140, Step:  8820, training loss: 240.852
# recon:  343, kl:     3, dir:  314, klf:    5, klw:    1
# Epoch:  141, Step:  8883, training loss: 238.038
# recon:  216, kl:    17, dir:  292, klf:    7, klw:    1
# Epoch:  142, Step:  8946, training loss: 240.868
# recon:  289, kl:     8, dir:  456, klf:    6, klw:    1
# Epoch:  143, Step:  9009, training loss: 236.731
# recon:  273, kl:     3, dir:  322, klf:    2, klw:    1
# Epoch:  144, Step:  9072, training loss: 233.391
# recon:  201, kl:     3, dir:  170, klf:    3, klw:    1
# Epoch:  145, Step:  9135, training loss: 233.424
# recon:   96, kl:     6, dir:   26, klf:    5, klw:    1
# Epoch:  146, Step:  9198, training loss: 233.700
# recon:   85, kl:     6, dir:    1, klf:    5, klw:    1
# Epoch:  147, Step:  9261, training loss: 233.944
# recon:  238, kl:     5, dir:  255, klf:    3, klw:    1
# Epoch:  148, Step:  9324, training loss: 232.757
# recon:  261, kl:     5, dir:  363, klf:    1, klw:    1
# Epoch:  149, Step:  9387, training loss: 233.960
# recon:  303, kl:    20, dir:  332, klf:   19, klw:    1
# Epoch:  150, Step:  9450, training loss: 240.756
# recon:  204, kl:     5, dir:  736, klf:    4, klw:    1
# Learning rate decreased to 0.00254187
# Epoch:  151, Step:  9513, training loss: 238.538
# recon:  194, kl:     9, dir:  792, klf:    5, klw:    1
# Epoch:  152, Step:  9576, training loss: 236.697
# recon:   79, kl:     7, dir:    0, klf:    4, klw:    1
# Epoch:  153, Step:  9639, training loss: 234.837
# recon:  437, kl:     5, dir:  920, klf:    3, klw:    1
# Epoch:  154, Step:  9702, training loss: 232.526
# recon:  211, kl:    32, dir:  191, klf:   17, klw:    1
# Epoch:  155, Step:  9765, training loss: 235.304
# recon:   97, kl:    15, dir:  408, klf:   11, klw:    1
# Epoch:  156, Step:  9828, training loss: 234.090
# recon:  237, kl:    32, dir:  316, klf:   14, klw:    1
# Epoch:  157, Step:  9891, training loss: 234.248
# recon:  124, kl:    10, dir:    5, klf:    5, klw:    1
# Epoch:  158, Step:  9954, training loss: 238.593
# recon:  201, kl:     3, dir:  210, klf:    6, klw:    1
# Learning rate decreased to 0.00228768
# Epoch:  159, Step: 10017, training loss: 250.349
# recon:  233, kl:    27, dir:  973, klf:    8, klw:    1
# Epoch:  160, Step: 10080, training loss: 241.046
# recon:   94, kl:     4, dir:  278, klf:    3, klw:    1
# Epoch:  161, Step: 10143, training loss: 240.494
# recon:  109, kl:     6, dir:    0, klf:    9, klw:    1
# Epoch:  162, Step: 10206, training loss: 229.920
# recon:  204, kl:     3, dir:  219, klf:    2, klw:    1
# Epoch:  163, Step: 10269, training loss: 236.682
# recon:  264, kl:     7, dir:  787, klf:    7, klw:    1
# Epoch:  164, Step: 10332, training loss: 231.395
# recon:   61, kl:     4, dir:   16, klf:    6, klw:    1
# Epoch:  165, Step: 10395, training loss: 231.821
# recon:  212, kl:     5, dir:  426, klf:    3, klw:    1
# Epoch:  166, Step: 10458, training loss: 237.933
# recon:   89, kl:     8, dir:    5, klf:    6, klw:    1
# Epoch:  167, Step: 10521, training loss: 231.373
# recon:  238, kl:    14, dir:  439, klf:   10, klw:    1
# Epoch:  168, Step: 10584, training loss: 235.313
# recon:  203, kl:    52, dir:  631, klf:   20, klw:    1
# Epoch:  169, Step: 10647, training loss: 231.522
# recon:  215, kl:     3, dir:  559, klf:    1, klw:    1
# Epoch:  170, Step: 10710, training loss: 232.252
# recon:   98, kl:     6, dir:    4, klf:    5, klw:    1
# Epoch:  171, Step: 10773, training loss: 236.847
# recon:  275, kl:    26, dir:  115, klf:    9, klw:    1
# Epoch:  172, Step: 10836, training loss: 226.241
# recon:   90, kl:     7, dir:   17, klf:    2, klw:    1
# Epoch:  173, Step: 10899, training loss: 227.215
# recon:   97, kl:    18, dir:  120, klf:   11, klw:    1
# Epoch:  174, Step: 10962, training loss: 230.185
# recon:   78, kl:     7, dir:    0, klf:    7, klw:    1
# Epoch:  175, Step: 11025, training loss: 232.254
# recon:   99, kl:     8, dir:   14, klf:    7, klw:    1
# Epoch:  176, Step: 11088, training loss: 236.526
# recon:  212, kl:     6, dir:  478, klf:    7, klw:    1
# Epoch:  177, Step: 11151, training loss: 229.580
# recon:   88, kl:     8, dir:    5, klf:    4, klw:    1
# Epoch:  178, Step: 11214, training loss: 230.141
# recon:  202, kl:     2, dir:  215, klf:    2, klw:    1
# Epoch:  179, Step: 11277, training loss: 242.064
# recon:  121, kl:     6, dir:   82, klf:    5, klw:    1
# Learning rate decreased to 0.00205891
# Epoch:  180, Step: 11340, training loss: 229.024
# recon:  147, kl:    12, dir:  369, klf:   13, klw:    1
# Epoch:  181, Step: 11403, training loss: 227.577
# recon:  205, kl:     3, dir:  377, klf:    3, klw:    1
# Epoch:  182, Step: 11466, training loss: 230.718
# recon:   78, kl:    12, dir:   15, klf:   12, klw:    1
# Epoch:  183, Step: 11529, training loss: 230.800
# recon:  200, kl:     5, dir:  236, klf:    3, klw:    1
# Epoch:  184, Step: 11592, training loss: 228.754
# recon:   79, kl:    14, dir:   17, klf:    7, klw:    1
# Epoch:  185, Step: 11655, training loss: 231.300
# recon:  193, kl:     7, dir: 1127, klf:    7, klw:    1
# Epoch:  186, Step: 11718, training loss: 235.478
# recon:  286, kl:    28, dir:  541, klf:   15, klw:    1
# Learning rate decreased to 0.00185302
# Epoch:  187, Step: 11781, training loss: 230.701
# recon:  234, kl:     7, dir:  282, klf:    2, klw:    1
# Epoch:  188, Step: 11844, training loss: 225.536
# recon:   74, kl:     4, dir:  214, klf:    4, klw:    1
# Epoch:  189, Step: 11907, training loss: 228.991
# recon:  128, kl:     9, dir:  343, klf:    8, klw:    1
# Epoch:  190, Step: 11970, training loss: 230.978
# recon:   86, kl:     5, dir:  678, klf:    4, klw:    1
# Epoch:  191, Step: 12033, training loss: 231.766
# recon:  289, kl:    41, dir: 20695, klf:   24, klw:    1
# Epoch:  192, Step: 12096, training loss: 233.579
# recon:  260, kl:    48, dir:  948, klf:   26, klw:    1
# Epoch:  193, Step: 12159, training loss: 227.531
# recon:  324, kl:     7, dir: 1195, klf:    7, klw:    1
# Epoch:  194, Step: 12222, training loss: 227.432
# recon:  162, kl:    27, dir:   99, klf:    8, klw:    1
# Epoch:  195, Step: 12285, training loss: 228.125
# recon:  303, kl:     5, dir:  353, klf:    2, klw:    1
# Epoch:  196, Step: 12348, training loss: 226.954
# recon:   90, kl:     5, dir:    0, klf:    5, klw:    1
# Epoch:  197, Step: 12411, training loss: 230.972
# recon:  204, kl:     3, dir:  335, klf:    2, klw:    1
# Epoch:  198, Step: 12474, training loss: 228.608
# recon:   91, kl:     5, dir:    5, klf:    2, klw:    1
# Epoch:  199, Step: 12537, training loss: 227.798
# recon:  202, kl:     3, dir:  714, klf:    5, klw:    1
# Epoch:  200, Step: 12600, training loss: 229.938
# recon:  224, kl:    15, dir:  311, klf:   14, klw:    1
# ...training complete.

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
print(output_valid.shape)
#model.plot_factors()
tt = np.zeros(((all_time-start_time),2))
sp = np.zeros(((all_time-start_time),neuron_num))
batch_size=1
gg = int(NRep/batch_size)
import math
def mutual_info(m):
    K=10
    h_y_xw = np.zeros(neuron_num)
    h_y_x = np.zeros(neuron_num)
    T = m.shape[0]
    for n in range(neuron_num):
        for k in range(K):
            h_y_xw_tem = 0
            h_y_x_tem = 0
            for t in range(T):
                h_y_xw_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)) * np.log(m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)))
                h_y_x_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k))
            h_y_xw[n] += h_y_xw_tem/T
            if h_y_x_tem < 1e-5:
                h_y_x_tem = 1e-5
            h_y_x[n] -= h_y_x_tem/T * math.log(h_y_x_tem/T)
            
    return  h_y_xw.sum()+h_y_x.sum()

for k in range(gg):
    t = model.infer_factors(output_valid[batch_size *k:batch_size *(k+1),:])
    #spi = model.reconstruct(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(spi.shape)
    for i in range(batch_size):
        for j in range(Time):
            tt[(i+batch_size*k)*Time+j,:] = t[i][j].to('cpu').detach().numpy().copy()
            #print(model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10))
            #print(mutual_info(y_hat))
            #obs_mc_mean = y_hat.mean(axis=0)
            #obs_mc_std = y_hat.std(axis=0)
            #print(poisson_entropy(np.round(obs_mc_mean)))
            #for l in range(neuron_num):
                #sp[(i+batch_size*k)*Time+j,l] = spi[j][l]
plt.figure()
plt.plot(tt)
# Out:
# torch.Size([125, 20, 30])
# [<matplotlib.lines.Line2D at 0x15c5f67cac8>,
#  <matplotlib.lines.Line2D at 0x15c5f67cc18>]

# %%
next_state = model.transition_rnn(tt[:1,:])
print(next_state)
# Out:
# torch.Size([1, 2])
# (array([[-0.08269514, -0.4742021 ]], dtype=float32), array([[-1.148442 , -1.4537783]], dtype=float32))

# %% [markdown]
# ## Plot results summary

# %%
# for i in range(neuron_num):
    plt.figure()
    plt.plot(y_data[:,i], linewidth = 2)
    plt.plot(sp[:,i],'r',linewidth = 1)
    plt.title(i)
    plt.ylim(-2,20)
# Out:
# (-2, 20)

# %%
import funs
from scipy import signal
qz_mean_est = tt
#plt.plot(qz_mean_est[:,1])
qz_est_norm = qz_mean_est#np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
qz_est_norm[:,0] = signal.savgol_filter(qz_est_norm[:,0], 51, 5)
qz_est_norm[:,1] = signal.savgol_filter(qz_est_norm[:,1],51, 5)
plt.plot(qz_est_norm[:,0],qz_est_norm[:,1])
z_true_c = traj# - x_test.mean(axis=0)
z_true_norm = z_true_c#/np.linalg.norm(z_true_c)

R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
v_state = []
v_bin = 20
for xi in range(v_bin):
    for yi in range(v_bin):
        y_hat = model.mcdropout(output_valid[:batch_size,:],np.array([-8+xi*0.8,-8+yi*0.8]).dot(np.linalg.inv(R)),T=10)
        v_state.append(mutual_info(y_hat))
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
plt.figure(figsize=(14,8))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure(figsize=(5,5))
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')

# %%
import numpy as np
import matplotlib.pyplot as plt
import grid_world

# agentの生成
agent = grid_world.Agent([0,0])

num_row = v_bin
num_col = v_bin
       
X, Y = np.mgrid[-8:-8+v_bin*0.8:16/20, -8:-8+v_bin*0.8:16/20]
print(X[1]*2)
X[1] = X[1]
z=np.zeros([v_bin,v_bin])
for i in range(v_bin):
    for j in range(v_bin):
        z[i,j] = v_state[v_bin*i+j]
fig, ax = plt.subplots()
im = ax.pcolormesh(X, Y, z, cmap='inferno',vmin=0,vmax=3)
ax.set_xlabel("X")
ax.set_ylabel("Y")
cbar = fig.colorbar(im)
cbar.set_label("Z")
plt.show()
fig.savefig("./gif/img22.png")
#grid_world.pi_arrow_plot(pi)
#grid_world.V_value_plot(V)
from PIL import Image
import glob

files = sorted(glob.glob('./gif/*.png'))  
images = list(map(lambda file : Image.open(file) , files))
images[0].save('image.gif' , save_all = True , append_images = images[1:] , duration = 200 , loop = 0)
# Out:
# [-14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4
#  -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4 -14.4]
