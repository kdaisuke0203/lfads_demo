# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

import os
import yaml
import math
from lfads_k09 import LFADS_Net
from utils import read_data, load_parameters, save_parameters
import scipy.io
# plt.style.use('dark_background')
import shutil
path = './models_k09'
if os.path.isdir(path): 
    shutil.rmtree(path)

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cpu

# %% [markdown]
# ## Load or Generate Data

# %%
all_time =28000
start_time = 25000
Time = 100 #600 not so good, 60 soso
datax = scipy.io.loadmat("spike83_k09_35000.mat")
y_data0 = datax["spike83_k09_35000"][:,start_time:all_time].T
traj = scipy.io.loadmat("trj83_k09_35000.mat")
traj = traj["trj83_k09_35000"][:,start_time:all_time].T
good_neuron_id = [0,1,4,9,12,13,14,15,16,17,19,20,21,22,24,25,26,29,31,35,36,40,41,43,48,49,52,56,59,60,63,69,71,72,75,79,80,81]
neuron_num = len(good_neuron_id)
NRep=int((all_time-start_time)/Time)
output = np.zeros((NRep,Time,neuron_num))
y_data = np.zeros((all_time-start_time,neuron_num))
for i in range(neuron_num):
    y_data[:,i] = y_data0[:,good_neuron_id[i]]
print(y_data.shape)
for i in range(all_time-start_time):
    for j in range(neuron_num):
        if y_data[i][j] > 30:
            y_data[i][j] = 30
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
output = output.astype('float32')
output = torch.Tensor(output).to(device)
print(output.shape)
output_valid = output.detach().clone()
# Out:
# (3000, 38)
# torch.Size([30, 100, 38])

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
train_ds      = torch.utils.data.TensorDataset(output)
valid_ds      = torch.utils.data.TensorDataset(output)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
plt.figure(figsize = (12,12))
plt.imshow(y_data.T, cmap=plt.cm.plasma,aspect='auto')
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
# Out:
# (100, 38)

# %%
#for i in range(neuron_num):
    #fig, ax = plt.subplots()
    #mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=10,s=3)
    #fig.colorbar(mappable)
    #plt.title(i)
    #plt.show()
#fig.savefig("img.png")

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters_k09.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# C:\Users\flab\prog\lfads_torch_k09_83\utils.py:91: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(open(path))
# {'dataset_name': 'chaotic_rnn',
#  'run_name': 'demo',
#  'g_dim': 30,
#  'u_dim': 10,
#  'factors_dim': 2,
#  'g0_encoder_dim': 30,
#  'c_encoder_dim': 10,
#  'controller_dim': 30,
#  'g0_prior_kappa': 0.1,
#  'u_prior_kappa': 0.1,
#  'keep_prob': 0.95,
#  'clip_val': 5.0,
#  'max_norm': 200,
#  'learning_rate': 0.01,
#  'learning_rate_min': 1e-05,
#  'learning_rate_decay': 0.9,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'scheduler_cooldown': 6,
#  'kl_weight_schedule_start': 0,
#  'kl_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'l2_weight_schedule_dur': 2000,
#  'epsilon': 0.1,
#  'betas': (0.9, 0.99),
#  'l2_gen_scale': 2000,
#  'l2_con_scale': 0}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = neuron_num, T = Time, dt = 1, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 2625

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')
batch_size = 10
"""tt = np.empty((3000,2))
for k in range(10):
    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t[90].shape)
    for i in range(batch_size):
        for j in range(100):
            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)"""
# Out:
# "tt = np.empty((3000,2))\nfor k in range(10):\n    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])\n    #print(t[90].shape)\n    for i in range(batch_size):\n        for j in range(100):\n            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()\nplt.figure()\nplt.plot(tt)"

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=300, batch_size=batch_size , use_tensorboard=False,
          train_truth=train_ds, valid_truth=valid_ds)
# Out:
# Beginning training...
# Epoch:    1, Step:     3, training loss: 5658.621
# recon: 5054, kl:     0, dir: 9545.45, smo:    0, klf:    0, klw: 0.001500
# Epoch:    2, Step:     6, training loss: 4818.566
# recon: 4432, kl:     1, dir: 6002.12, smo:    0, klf:    0, klw: 0.003000
# Epoch:    3, Step:     9, training loss: 4714.338
# recon: 4755, kl:     3, dir: 3915.45, smo:    0, klf:    0, klw: 0.004500
# Epoch:    4, Step:    12, training loss: 4686.806
# recon: 4433, kl:     4, dir: 1987.52, smo:    0, klf:    0, klw: 0.006000
# Epoch:    5, Step:    15, training loss: 4661.605
# recon: 4548, kl:     5, dir: 1320.96, smo:    0, klf:    0, klw: 0.007500
# Epoch:    6, Step:    18, training loss: 4603.017
# recon: 5155, kl:     7, dir: 1141.98, smo:    0, klf:    0, klw: 0.009000
# Epoch:    7, Step:    21, training loss: 4519.287
# recon: 4235, kl:     7, dir: 697.70, smo:    0, klf:    0, klw: 0.010500
# Epoch:    8, Step:    24, training loss: 4382.562
# recon: 4395, kl:     8, dir: 767.21, smo:    0, klf:    0, klw: 0.012000
# Epoch:    9, Step:    27, training loss: 4302.762
# recon: 4272, kl:    10, dir: 789.96, smo:    0, klf:    1, klw: 0.013500
# Epoch:   10, Step:    30, training loss: 4285.973
# recon: 4064, kl:    10, dir: 708.58, smo:    0, klf:    0, klw: 0.015000
# Epoch:   11, Step:    33, training loss: 4233.799
# recon: 3963, kl:    11, dir: 663.09, smo:    0, klf:    1, klw: 0.016500
# Epoch:   12, Step:    36, training loss: 4195.749
# recon: 3970, kl:    11, dir: 646.06, smo:    0, klf:    1, klw: 0.018000
# Epoch:   13, Step:    39, training loss: 4142.319
# recon: 4212, kl:    11, dir: 667.07, smo:    0, klf:    1, klw: 0.019500
# Epoch:   14, Step:    42, training loss: 4070.158
# recon: 4399, kl:    10, dir: 851.52, smo:    0, klf:    1, klw: 0.021000
# Epoch:   15, Step:    45, training loss: 3962.846
# recon: 4049, kl:    10, dir: 781.70, smo:    0, klf:    1, klw: 0.022500
# Epoch:   16, Step:    48, training loss: 3875.633
# recon: 4049, kl:    10, dir: 846.14, smo:    0, klf:    1, klw: 0.024000
# Epoch:   17, Step:    51, training loss: 3819.279
# recon: 3768, kl:    10, dir: 886.75, smo:    0, klf:    1, klw: 0.025500
# Epoch:   18, Step:    54, training loss: 3741.548
# recon: 3844, kl:    10, dir: 902.55, smo:    0, klf:    1, klw: 0.027000
# Epoch:   19, Step:    57, training loss: 3706.578
# recon: 3080, kl:    11, dir: 543.90, smo:    0, klf:    2, klw: 0.028500
# Epoch:   20, Step:    60, training loss: 3677.251
# recon: 3715, kl:    12, dir: 814.29, smo:    0, klf:    2, klw: 0.030000
# Epoch:   21, Step:    63, training loss: 3646.676
# recon: 3813, kl:    12, dir: 861.23, smo:    0, klf:    2, klw: 0.031500
# Epoch:   22, Step:    66, training loss: 3633.433
# recon: 3696, kl:    11, dir: 758.54, smo:    0, klf:    2, klw: 0.033000
# Epoch:   23, Step:    69, training loss: 3606.435
# recon: 3424, kl:    11, dir: 723.10, smo:    0, klf:    2, klw: 0.034500
# Epoch:   24, Step:    72, training loss: 3570.179
# recon: 3455, kl:    12, dir: 920.10, smo:    0, klf:    2, klw: 0.036000
# Epoch:   25, Step:    75, training loss: 3541.447
# recon: 3706, kl:    12, dir: 846.42, smo:    0, klf:    2, klw: 0.037500
# Epoch:   26, Step:    78, training loss: 3509.771
# recon: 3683, kl:    12, dir: 883.92, smo:    0, klf:    3, klw: 0.039000
# Epoch:   27, Step:    81, training loss: 3477.637
# recon: 3554, kl:    13, dir: 734.58, smo:    0, klf:    3, klw: 0.040500
# Epoch:   28, Step:    84, training loss: 3481.318
# Epoch:   51, Step:   153, training loss: 3238.966
# recon: 3306, kl:    20, dir: 363.57, smo:    0, klf:    6, klw: 0.076500
# Epoch:   52, Step:   156, training loss: 3236.076
# recon: 3141, kl:    20, dir: 348.35, smo:    0, klf:    6, klw: 0.078000
# Epoch:   53, Step:   159, training loss: 3236.163
# recon: 3123, kl:    20, dir: 356.40, smo:    0, klf:    6, klw: 0.079500
# Epoch:   54, Step:   162, training loss: 3221.538
# recon: 3329, kl:    21, dir: 354.76, smo:    0, klf:    7, klw: 0.081000
# Epoch:   55, Step:   165, training loss: 3226.747
# recon: 3264, kl:    21, dir: 355.67, smo:    0, klf:    6, klw: 0.082500
# Epoch:   56, Step:   168, training loss: 3210.105
# recon: 3030, kl:    21, dir: 335.71, smo:    0, klf:    7, klw: 0.084000
# Epoch:   57, Step:   171, training loss: 3219.736
# recon: 3024, kl:    21, dir: 329.00, smo:    0, klf:    7, klw: 0.085500
# Epoch:   58, Step:   174, training loss: 3216.276
# recon: 3461, kl:    22, dir: 387.56, smo:    0, klf:    7, klw: 0.087000
# Epoch:   59, Step:   177, training loss: 3204.211
# recon: 2921, kl:    22, dir: 240.83, smo:    0, klf:    7, klw: 0.088500
# Epoch:   60, Step:   180, training loss: 3197.140
# recon: 3416, kl:    23, dir: 331.20, smo:    0, klf:    8, klw: 0.090000
# Epoch:   61, Step:   183, training loss: 3200.110
# recon: 2972, kl:    22, dir: 251.64, smo:    0, klf:    8, klw: 0.091500
# Epoch:   62, Step:   186, training loss: 3193.009
# recon: 2927, kl:    23, dir: 282.00, smo:    0, klf:    8, klw: 0.093000
# Epoch:   63, Step:   189, training loss: 3191.770
# recon: 3126, kl:    23, dir: 301.94, smo:    0, klf:    8, klw: 0.094500
# Epoch:   64, Step:   192, training loss: 3183.124
# recon: 3066, kl:    23, dir: 248.38, smo:    0, klf:    8, klw: 0.096000
# Epoch:   65, Step:   195, training loss: 3182.267
# recon: 2955, kl:    23, dir: 250.25, smo:    0, klf:    8, klw: 0.097500
# Epoch:   66, Step:   198, training loss: 3170.687
# recon: 3226, kl:    23, dir: 334.39, smo:    0, klf:    8, klw: 0.099000
# Epoch:   67, Step:   201, training loss: 3190.358
# recon: 3208, kl:    24, dir: 285.14, smo:    0, klf:    8, klw: 0.100500
# Epoch:   68, Step:   204, training loss: 3181.935
# recon: 3056, kl:    24, dir: 276.34, smo:    0, klf:    9, klw: 0.102000
# Epoch:   69, Step:   207, training loss: 3174.537
# recon: 3150, kl:    25, dir: 315.52, smo:    0, klf:    9, klw: 0.103500
# Epoch:   70, Step:   210, training loss: 3187.796
# recon: 3103, kl:    25, dir: 316.72, smo:    0, klf:    9, klw: 0.105000
# Epoch:   71, Step:   213, training loss: 3167.608
# recon: 2892, kl:    25, dir: 285.30, smo:    0, klf:    9, klw: 0.106500
# Epoch:   72, Step:   216, training loss: 3184.626
# recon: 3174, kl:    26, dir: 297.01, smo:    0, klf:    9, klw: 0.108000
# Epoch:  139, Step:   417, training loss: 3052.365
# recon: 2791, kl:    42, dir: 145.80, smo:    0, klf:   19, klw: 0.208500
# Epoch:  140, Step:   420, training loss: 3056.085
# recon: 2990, kl:    42, dir: 170.06, smo:    0, klf:   20, klw: 0.210000
# Learning rate decreased to 0.00656100
# Epoch:  141, Step:   423, training loss: 3043.072
# recon: 2960, kl:    44, dir: 201.29, smo:    0, klf:   20, klw: 0.211500
# Epoch:  142, Step:   426, training loss: 3060.458
# recon: 2971, kl:    43, dir: 154.67, smo:    0, klf:   20, klw: 0.213000
# Epoch:  143, Step:   429, training loss: 3054.693
# recon: 3107, kl:    44, dir: 173.46, smo:    0, klf:   20, klw: 0.214500
# Epoch:  144, Step:   432, training loss: 3071.051
# recon: 3196, kl:    44, dir: 167.81, smo:    0, klf:   20, klw: 0.216000
# Epoch:  145, Step:   435, training loss: 3055.263
# recon: 2932, kl:    43, dir: 126.58, smo:    0, klf:   20, klw: 0.217500
# Epoch:  146, Step:   438, training loss: 3051.470
# recon: 2923, kl:    43, dir: 152.44, smo:    0, klf:   21, klw: 0.219000
# Epoch:  147, Step:   441, training loss: 3035.834
# recon: 3055, kl:    44, dir: 156.43, smo:    0, klf:   20, klw: 0.220500
# Epoch:  148, Step:   444, training loss: 3028.890
# recon: 2946, kl:    43, dir: 153.22, smo:    0, klf:   21, klw: 0.222000
# Epoch:  149, Step:   447, training loss: 3016.907
# recon: 2880, kl:    43, dir: 163.59, smo:    0, klf:   21, klw: 0.223500
# Epoch:  150, Step:   450, training loss: 3045.258
# recon: 2923, kl:    45, dir: 175.34, smo:    0, klf:   21, klw: 0.225000
# Epoch:  151, Step:   453, training loss: 3028.187
# recon: 3044, kl:    44, dir: 158.71, smo:    0, klf:   21, klw: 0.226500
# Epoch:  152, Step:   456, training loss: 3038.501
# recon: 2998, kl:    45, dir: 179.65, smo:    0, klf:   21, klw: 0.228000
# Epoch:  153, Step:   459, training loss: 3030.446
# recon: 2958, kl:    44, dir: 161.86, smo:    0, klf:   21, klw: 0.229500
# Epoch:  154, Step:   462, training loss: 3033.154
# recon: 2822, kl:    42, dir: 112.33, smo:    0, klf:   21, klw: 0.231000
# Epoch:  155, Step:   465, training loss: 3035.411
# recon: 3090, kl:    46, dir: 191.44, smo:    0, klf:   22, klw: 0.232500
# Epoch:  156, Step:   468, training loss: 3027.959
# recon: 3049, kl:    44, dir: 127.63, smo:    0, klf:   22, klw: 0.234000
# Epoch:  157, Step:   471, training loss: 3043.880
# recon: 3156, kl:    47, dir: 156.26, smo:    0, klf:   22, klw: 0.235500
# Learning rate decreased to 0.00590490
# Epoch:  158, Step:   474, training loss: 3026.451
# recon: 2645, kl:    43, dir: 107.80, smo:    0, klf:   22, klw: 0.237000
# Epoch:  159, Step:   477, training loss: 3042.046
# recon: 3047, kl:    45, dir: 148.30, smo:    0, klf:   23, klw: 0.238500
# Epoch:  160, Step:   480, training loss: 3027.858
# recon: 2715, kl:    45, dir: 142.58, smo:    0, klf:   23, klw: 0.240000
# Epoch:  161, Step:   483, training loss: 3023.311
# recon: 3037, kl:    47, dir: 134.95, smo:    0, klf:   23, klw: 0.241500
# Epoch:  162, Step:   486, training loss: 3043.979
# recon: 3042, kl:    47, dir: 130.53, smo:    0, klf:   23, klw: 0.243000
# Epoch:  163, Step:   489, training loss: 3014.784
# recon: 3018, kl:    47, dir: 141.00, smo:    0, klf:   23, klw: 0.244500
# Epoch:  164, Step:   492, training loss: 3014.488
# recon: 3001, kl:    46, dir: 152.00, smo:    0, klf:   23, klw: 0.246000
# Epoch:  165, Step:   495, training loss: 3010.963
# recon: 2878, kl:    47, dir: 136.77, smo:    0, klf:   26, klw: 0.247500
# Epoch:  166, Step:   498, training loss: 3007.588
# recon: 3192, kl:    49, dir: 163.34, smo:    0, klf:   24, klw: 0.249000
# Epoch:  167, Step:   501, training loss: 3014.257
# recon: 3016, kl:    47, dir: 137.51, smo:    0, klf:   24, klw: 0.250500
# Epoch:  168, Step:   504, training loss: 3012.501
# recon: 2797, kl:    46, dir: 130.38, smo:    0, klf:   24, klw: 0.252000
# Epoch:  169, Step:   507, training loss: 3030.972
# recon: 2876, kl:    46, dir: 109.21, smo:    0, klf:   24, klw: 0.253500
# Learning rate decreased to 0.00531441
# Epoch:  170, Step:   510, training loss: 3024.678
# recon: 2944, kl:    47, dir: 132.77, smo:    0, klf:   24, klw: 0.255000
# Epoch:  171, Step:   513, training loss: 3008.349
# recon: 2968, kl:    46, dir: 121.52, smo:    0, klf:   25, klw: 0.256500
# Epoch:  172, Step:   516, training loss: 3006.896
# recon: 2979, kl:    48, dir: 140.60, smo:    0, klf:   25, klw: 0.258000
# Epoch:  173, Step:   519, training loss: 3031.883
# recon: 3135, kl:    49, dir: 157.15, smo:    0, klf:   25, klw: 0.259500
# Epoch:  174, Step:   522, training loss: 3014.686
# recon: 2948, kl:    48, dir: 134.41, smo:    0, klf:   25, klw: 0.261000
# Epoch:  175, Step:   525, training loss: 3032.438
# recon: 3067, kl:    49, dir: 131.10, smo:    0, klf:   25, klw: 0.262500
# Learning rate decreased to 0.00478297
# Epoch:  176, Step:   528, training loss: 3014.177
# recon: 3145, kl:    51, dir: 157.87, smo:    0, klf:   59, klw: 0.264000
# Epoch:  177, Step:   531, training loss: 3002.720
# recon: 2940, kl:    49, dir: 125.74, smo:    0, klf:   26, klw: 0.265500
# Epoch:  178, Step:   534, training loss: 3018.547
# recon: 2872, kl:    49, dir: 118.60, smo:    0, klf:   26, klw: 0.267000
# Epoch:  179, Step:   537, training loss: 3025.469
# recon: 3024, kl:    50, dir: 125.26, smo:    0, klf:   26, klw: 0.268500
# Epoch:  180, Step:   540, training loss: 3012.497
# recon: 3166, kl:    51, dir: 154.25, smo:    0, klf:   27, klw: 0.270000
# Epoch:  181, Step:   543, training loss: 3027.691
# recon: 2865, kl:    49, dir: 122.97, smo:    0, klf:   27, klw: 0.271500
# Epoch:  182, Step:   546, training loss: 3016.802
# recon: 2914, kl:    52, dir: 115.94, smo:    0, klf:   31, klw: 0.306000
# Epoch:  205, Step:   615, training loss: 2998.388
# recon: 2873, kl:    52, dir: 118.32, smo:    0, klf:   30, klw: 0.307500
# Epoch:  206, Step:   618, training loss: 2998.075
# recon: 2753, kl:    51, dir: 118.44, smo:    0, klf:   30, klw: 0.309000
# Epoch:  207, Step:   621, training loss: 2990.839
# recon: 2930, kl:    52, dir: 117.73, smo:    0, klf:   30, klw: 0.310500
# Epoch:  208, Step:   624, training loss: 3000.738
# recon: 3121, kl:    54, dir: 120.18, smo:    0, klf:   31, klw: 0.312000
# Epoch:  209, Step:   627, training loss: 2997.893
# recon: 2936, kl:    54, dir: 120.71, smo:    0, klf:   31, klw: 0.313500
# Epoch:  210, Step:   630, training loss: 2992.249
# recon: 2789, kl:    51, dir: 98.74, smo:    0, klf:   30, klw: 0.315000
# Epoch:  211, Step:   633, training loss: 3013.130
# recon: 2979, kl:    52, dir: 92.29, smo:    0, klf:   30, klw: 0.316500
# Learning rate decreased to 0.00387420
# Epoch:  212, Step:   636, training loss: 2994.314
# recon: 2907, kl:    53, dir: 107.70, smo:    0, klf:   31, klw: 0.318000
# Epoch:  213, Step:   639, training loss: 3021.493
# recon: 2884, kl:    52, dir: 86.72, smo:    0, klf:   30, klw: 0.319500
# Epoch:  214, Step:   642, training loss: 3007.296
# recon: 2941, kl:    52, dir: 101.01, smo:    0, klf:   31, klw: 0.321000
# Epoch:  215, Step:   645, training loss: 3017.651
# recon: 2972, kl:    55, dir: 113.67, smo:    0, klf:   31, klw: 0.322500
# Epoch:  216, Step:   648, training loss: 3008.361
# recon: 2940, kl:    54, dir: 108.63, smo:    0, klf:   32, klw: 0.324000
# Epoch:  217, Step:   651, training loss: 3004.607
# recon: 3022, kl:    55, dir: 131.96, smo:    0, klf:   32, klw: 0.325500
# Epoch:  218, Step:   654, training loss: 3001.025
# recon: 3225, kl:    57, dir: 123.79, smo:    0, klf:   32, klw: 0.327000
# Epoch:  219, Step:   657, training loss: 2995.509
# recon: 2929, kl:    55, dir: 109.56, smo:    0, klf:   32, klw: 0.328500
# Epoch:  220, Step:   660, training loss: 2998.713
# recon: 2933, kl:    56, dir: 124.40, smo:    0, klf:   32, klw: 0.330000
# Epoch:  221, Step:   663, training loss: 3011.012
# recon: 2827, kl:    55, dir: 105.61, smo:    0, klf:   32, klw: 0.331500
# Epoch:  222, Step:   666, training loss: 3004.161
# recon: 3084, kl:    55, dir: 104.59, smo:    0, klf:   33, klw: 0.333000
# Epoch:  223, Step:   669, training loss: 2989.512
# recon: 3013, kl:    56, dir: 100.55, smo:    0, klf:   32, klw: 0.334500
# Epoch:  224, Step:   672, training loss: 2990.722
# recon: 2625, kl:    54, dir: 92.22, smo:    0, klf:   32, klw: 0.336000
# Epoch:  225, Step:   675, training loss: 3002.699
# recon: 3035, kl:    58, dir: 134.05, smo:    0, klf:   33, klw: 0.337500
# Epoch:  226, Step:   678, training loss: 2999.641
# recon: 2995, kl:    57, dir: 139.01, smo:    0, klf:   33, klw: 0.339000
# Epoch:  227, Step:   681, training loss: 2988.477
# recon: 3086, kl:    59, dir: 140.63, smo:    0, klf:   35, klw: 0.340500
# Epoch:  228, Step:   684, training loss: 2998.799
# recon: 2818, kl:    54, dir: 77.29, smo:    0, klf:   34, klw: 0.342000
# Epoch:  229, Step:   687, training loss: 3001.516
# recon: 2938, kl:    56, dir: 99.32, smo:    0, klf:   33, klw: 0.343500
# Epoch:  230, Step:   690, training loss: 2997.468
# recon: 2795, kl:    55, dir: 99.29, smo:    0, klf:   33, klw: 0.345000
# Epoch:  231, Step:   693, training loss: 2995.413
# recon: 2810, kl:    55, dir: 89.96, smo:    0, klf:   34, klw: 0.346500
# Epoch:  232, Step:   696, training loss: 2992.877
# recon: 2730, kl:    55, dir: 104.79, smo:    0, klf:   34, klw: 0.348000
# Epoch:  233, Step:   699, training loss: 2985.188
# recon: 2824, kl:    56, dir: 105.30, smo:    0, klf:   34, klw: 0.349500
# Epoch:  234, Step:   702, training loss: 2985.387
# recon: 2789, kl:    54, dir: 89.39, smo:    0, klf:   34, klw: 0.351000
# Epoch:  235, Step:   705, training loss: 2977.802
# recon: 2800, kl:    56, dir: 96.50, smo:    0, klf:   34, klw: 0.352500
# Epoch:  236, Step:   708, training loss: 2994.534
# recon: 2998, kl:    59, dir: 124.73, smo:    0, klf:   34, klw: 0.354000
# Epoch:  237, Step:   711, training loss: 2996.950
# recon: 2891, kl:    55, dir: 78.38, smo:    0, klf:   34, klw: 0.355500
# Learning rate decreased to 0.00348678
# Epoch:  238, Step:   714, training loss: 2989.564
# recon: 2764, kl:    54, dir: 90.27, smo:    0, klf:   35, klw: 0.357000
# Epoch:  239, Step:   717, training loss: 3007.755
# recon: 2800, kl:    55, dir: 91.24, smo:    0, klf:   35, klw: 0.358500
# Epoch:  240, Step:   720, training loss: 2991.719
# recon: 2799, kl:    55, dir: 80.73, smo:    0, klf:   35, klw: 0.360000
# Epoch:  241, Step:   723, training loss: 2980.816
# recon: 2845, kl:    58, dir: 111.34, smo:    0, klf:   36, klw: 0.361500
# Epoch:  242, Step:   726, training loss: 2984.826
# recon: 2761, kl:    56, dir: 91.43, smo:    0, klf:   36, klw: 0.363000
# Epoch:  243, Step:   729, training loss: 2996.998
# recon: 2715, kl:    56, dir: 85.48, smo:    0, klf:   35, klw: 0.364500
# Epoch:  244, Step:   732, training loss: 2996.965
# recon: 2891, kl:    57, dir: 87.79, smo:    0, klf:   36, klw: 0.366000
# Epoch:  245, Step:   735, training loss: 2996.527
# recon: 2884, kl:    57, dir: 91.20, smo:    0, klf:   35, klw: 0.367500
# Epoch:  246, Step:   738, training loss: 2998.161
# recon: 2863, kl:    58, dir: 83.96, smo:    0, klf:   35, klw: 0.369000
# Learning rate decreased to 0.00313811
# Epoch:  247, Step:   741, training loss: 2983.554
# recon: 2774, kl:    55, dir: 85.83, smo:    0, klf:   36, klw: 0.370500
# Epoch:  248, Step:   744, training loss: 2996.245
# recon: 2936, kl:    57, dir: 91.98, smo:    0, klf:   36, klw: 0.372000
# Epoch:  249, Step:   747, training loss: 2992.496
# recon: 3032, kl:    59, dir: 106.79, smo:    0, klf:   39, klw: 0.373500
# Epoch:  250, Step:   750, training loss: 3001.838
# recon: 2811, kl:    58, dir: 103.67, smo:    0, klf:   36, klw: 0.375000
# Epoch:  251, Step:   753, training loss: 3008.370
# recon: 2728, kl:    55, dir: 83.52, smo:    0, klf:   37, klw: 0.376500
# Epoch:  252, Step:   756, training loss: 2989.141
# recon: 2744, kl:    57, dir: 76.90, smo:    0, klf:   37, klw: 0.378000
# Epoch:  253, Step:   759, training loss: 2998.591
# recon: 2995, kl:    61, dir: 105.22, smo:    0, klf:   37, klw: 0.379500
# Epoch:  254, Step:   762, training loss: 2990.340
# recon: 2827, kl:    56, dir: 70.42, smo:    0, klf:   37, klw: 0.381000
# Epoch:  255, Step:   765, training loss: 3005.385
# recon: 2774, kl:    58, dir: 85.55, smo:    0, klf:   37, klw: 0.382500
# Epoch:  256, Step:   768, training loss: 3008.018
# recon: 3045, kl:    60, dir: 106.20, smo:    0, klf:   42, klw: 0.384000
# Epoch:  257, Step:   771, training loss: 2991.370
# recon: 2836, kl:    58, dir: 75.07, smo:    0, klf:   38, klw: 0.385500
# Epoch:  258, Step:   774, training loss: 2988.597
# recon: 2715, kl:    56, dir: 74.26, smo:    0, klf:   38, klw: 0.387000
# Epoch:  259, Step:   777, training loss: 2990.828
# recon: 2761, kl:    57, dir: 88.02, smo:    0, klf:   37, klw: 0.388500
# Epoch:  260, Step:   780, training loss: 2977.256
# recon: 2848, kl:    59, dir: 88.76, smo:    0, klf:   38, klw: 0.390000
# Epoch:  261, Step:   783, training loss: 2987.277
# recon: 2963, kl:    61, dir: 100.63, smo:    0, klf:   39, klw: 0.391500
# Epoch:  262, Step:   786, training loss: 2983.474
# recon: 2964, kl:    59, dir: 83.34, smo:    0, klf:   39, klw: 0.393000
# Epoch:  263, Step:   789, training loss: 2987.223
# recon: 2889, kl:    59, dir: 88.62, smo:    0, klf:   39, klw: 0.394500
# Epoch:  264, Step:   792, training loss: 2986.464
# recon: 2928, kl:    60, dir: 72.49, smo:    0, klf:   39, klw: 0.396000
# Epoch:  265, Step:   795, training loss: 2992.432
# recon: 3035, kl:    61, dir: 103.94, smo:    0, klf:   39, klw: 0.397500
# Learning rate decreased to 0.00282430
# Epoch:  266, Step:   798, training loss: 3002.811
# recon: 2743, kl:    59, dir: 101.08, smo:    0, klf:   38, klw: 0.399000
# Epoch:  267, Step:   801, training loss: 3000.070
# recon: 3003, kl:    60, dir: 86.47, smo:    0, klf:   39, klw: 0.400500
# Epoch:  268, Step:   804, training loss: 3006.893
# recon: 2856, kl:    59, dir: 89.68, smo:    0, klf:   39, klw: 0.402000
# Epoch:  269, Step:   807, training loss: 2981.638
# recon: 2839, kl:    59, dir: 70.85, smo:    0, klf:   39, klw: 0.403500
# Epoch:  270, Step:   810, training loss: 2979.359
# recon: 2923, kl:    59, dir: 95.00, smo:    0, klf:   40, klw: 0.405000
# Epoch:  271, Step:   813, training loss: 3007.952
# recon: 2587, kl:    57, dir: 75.32, smo:    0, klf:   39, klw: 0.406500
# Learning rate decreased to 0.00254187
# Epoch:  272, Step:   816, training loss: 3000.083
# recon: 2927, kl:    60, dir: 92.36, smo:    0, klf:   40, klw: 0.408000
# Epoch:  273, Step:   819, training loss: 2991.441
# recon: 2985, kl:    60, dir: 90.38, smo:    0, klf:   41, klw: 0.409500
# Epoch:  274, Step:   822, training loss: 2990.375
# recon: 2927, kl:    61, dir: 73.74, smo:    0, klf:   40, klw: 0.411000
# Epoch:  275, Step:   825, training loss: 2991.831
# recon: 2763, kl:    59, dir: 84.87, smo:    0, klf:   40, klw: 0.412500
# Epoch:  276, Step:   828, training loss: 2996.064
# recon: 3092, kl:    63, dir: 89.33, smo:    0, klf:   41, klw: 0.414000
# Epoch:  277, Step:   831, training loss: 2983.024
# recon: 2806, kl:    62, dir: 92.55, smo:    0, klf:   41, klw: 0.415500
# Epoch:  278, Step:   834, training loss: 2986.635
# recon: 2936, kl:    61, dir: 81.69, smo:    0, klf:   41, klw: 0.417000
# Epoch:  279, Step:   837, training loss: 2968.810
# recon: 2832, kl:    61, dir: 67.80, smo:    0, klf:   41, klw: 0.418500
# Epoch:  280, Step:   840, training loss: 2982.370
# recon: 2841, kl:    62, dir: 72.75, smo:    0, klf:   41, klw: 0.420000
# Epoch:  281, Step:   843, training loss: 2984.056
# recon: 2480, kl:    57, dir: 53.67, smo:    0, klf:   41, klw: 0.421500
# Epoch:  282, Step:   846, training loss: 2996.716
# recon: 2731, kl:    59, dir: 70.59, smo:    0, klf:   41, klw: 0.423000
# Learning rate decreased to 0.00228768
# Epoch:  283, Step:   849, training loss: 2995.971
# recon: 2803, kl:    59, dir: 85.96, smo:    0, klf:   42, klw: 0.424500
# Epoch:  284, Step:   852, training loss: 2998.023
# recon: 2853, kl:    62, dir: 79.47, smo:    0, klf:   43, klw: 0.426000
# Epoch:  285, Step:   855, training loss: 2986.754
# recon: 2824, kl:    60, dir: 80.07, smo:    0, klf:   43, klw: 0.427500
# Epoch:  286, Step:   858, training loss: 3013.928
# recon: 2973, kl:    62, dir: 84.24, smo:    0, klf:   42, klw: 0.429000
# Epoch:  287, Step:   861, training loss: 3001.332
# recon: 2785, kl:    59, dir: 74.62, smo:    0, klf:   42, klw: 0.430500
# Epoch:  288, Step:   864, training loss: 2996.885
# recon: 2935, kl:    64, dir: 91.56, smo:    0, klf:   43, klw: 0.432000
# Epoch:  289, Step:   867, training loss: 2988.506
# recon: 2973, kl:    64, dir: 92.74, smo:    0, klf:   44, klw: 0.433500
# Epoch:  290, Step:   870, training loss: 2980.378
# recon: 2870, kl:    64, dir: 87.97, smo:    0, klf:   44, klw: 0.435000
# Epoch:  291, Step:   873, training loss: 2990.450
# recon: 3263, kl:    67, dir: 100.73, smo:    0, klf:   45, klw: 0.436500
# Epoch:  292, Step:   876, training loss: 2990.365
# recon: 2925, kl:    65, dir: 94.04, smo:    0, klf:   43, klw: 0.438000
# Epoch:  293, Step:   879, training loss: 2996.647
# recon: 2968, kl:    66, dir: 101.70, smo:    0, klf:   43, klw: 0.439500
# Epoch:  294, Step:   882, training loss: 2984.412
# recon: 2838, kl:    62, dir: 78.28, smo:    0, klf:   43, klw: 0.441000
# Epoch:  295, Step:   885, training loss: 2985.303
# recon: 2585, kl:    59, dir: 63.89, smo:    0, klf:   43, klw: 0.442500
# Epoch:  296, Step:   888, training loss: 2979.199
# recon: 2991, kl:    65, dir: 105.98, smo:    0, klf:   45, klw: 0.444000
# Epoch:  297, Step:   891, training loss: 2978.886
# recon: 2689, kl:    62, dir: 77.79, smo:    0, klf:   44, klw: 0.445500
# Epoch:  298, Step:   894, training loss: 2992.515
# recon: 2901, kl:    65, dir: 84.65, smo:    0, klf:   44, klw: 0.447000
# Epoch:  299, Step:   897, training loss: 2990.939
# recon: 3001, kl:    65, dir: 76.48, smo:    0, klf:   44, klw: 0.448500
# Epoch:  300, Step:   900, training loss: 3002.303
# recon: 2730, kl:    62, dir: 69.95, smo:    0, klf:   46, klw: 0.450000
# Learning rate decreased to 0.00205891
# ...training complete.

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
print(output_valid.shape)
#model.plot_factors()
tt = np.zeros(((all_time-start_time),2))
sp = np.zeros(((all_time-start_time),neuron_num))
batch_size=1
gg = int(NRep/batch_size)
import math
def mutual_info(m):
    K=30
    h_y_xw = np.zeros(neuron_num)
    h_y_x = np.zeros(neuron_num)
    T = m.shape[0]
    for n in range(neuron_num):
        for k in range(K):
            h_y_xw_tem = 0
            h_y_x_tem = 0
            for t in range(T):
                h_y_xw_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)) * np.log(m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)))
                h_y_x_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k))
            h_y_xw[n] += h_y_xw_tem/T
            h_y_x[n] -= h_y_x_tem/T * math.log(h_y_x_tem/T)
            
    return  h_y_xw.sum(), h_y_x.sum()

for k in range(gg):
    t = model.infer_factors(output_valid[batch_size *k:batch_size *(k+1),:])
    spi = model.reconstruct(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(spi.shape)
    for i in range(batch_size):
        for j in range(Time):
            tt[(i+batch_size*k)*Time+j,:] = t[i][j].to('cpu').detach().numpy().copy()
            #print(model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10))
            #y_hat = model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10)
            #print(mutual_info(y_hat))
            #obs_mc_mean = y_hat.mean(axis=0)
            #obs_mc_std = y_hat.std(axis=0)
            #print(poisson_entropy(np.round(obs_mc_mean)))
            for l in range(neuron_num):
                sp[(i+batch_size*k)*Time+j,l] = spi[j][l]
plt.figure()
plt.plot(tt)
# Out:
# torch.Size([30, 100, 38])
# [<matplotlib.lines.Line2D at 0x1d1de8f6e10>,
#  <matplotlib.lines.Line2D at 0x1d1de8f6f60>]

# %%
#next_state = model.transition_rnn(tt[:1,:])
#print(next_state)

# %% [markdown]
# ## Plot results summary

# %%
"""for i in range(neuron_num):
    plt.figure()
    plt.plot(y_data[:,i], linewidth = 2)
    plt.plot(sp[:,i],'r',linewidth = 1)
    plt.title(i)
    plt.ylim(-2,20)"""
# Out:
# "for i in range(neuron_num):\n    plt.figure()\n    plt.plot(y_data[:,i], linewidth = 2)\n    plt.plot(sp[:,i],'r',linewidth = 1)\n    plt.title(i)\n    plt.ylim(-2,20)"

# %%
import funs
from scipy import signal
qz_mean_est = tt
#plt.plot(qz_mean_est[:,1])
qz_est_norm = qz_mean_est#np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
qz_est_norm[:,0] = signal.savgol_filter(qz_est_norm[:,0], 11, 5)
qz_est_norm[:,1] = signal.savgol_filter(qz_est_norm[:,1],11, 5)
plt.plot(qz_est_norm[:,0],qz_est_norm[:,1])
z_true_c = traj# - x_test.mean(axis=0)
z_true_norm = z_true_c#/np.linalg.norm(z_true_c)

R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

#qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 21, 5)
#qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],21, 5)
st=0
en=4000
plt.figure(figsize=(14,8))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[st:en,0],'r', linewidth = 1, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[st:en,0], 'k', linewidth = 1, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[st:en,1],'r', linewidth = 1, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[st:en,1], 'k', linewidth = 1, label = '\"true\" mean')

fig = plt.figure(figsize=(5,5))
plt.plot(z_true_norm[st:en,0], z_true_norm[st:en,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[st:en,0], qz_est_norm_R[st:en,1], lw=2, color = 'r')

# %%
#np.savetxt('lfads_k09_01181250_good.csv', tt, delimiter=',')

# %%
# %matplotlib nbagg

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

#fig = plt.figure()
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(8, 4))
ims = []
for i in range(2000):
    x_list = []
    y_list = []
    x_list2 = []
    y_list2 = []
    for j in range(i):
        x = qz_est_norm_R[j,0]
        y = qz_est_norm_R[j,1]
        x2 = z_true_norm[j,0]
        y2 = z_true_norm[j,1]
        x_list.append(x)
        y_list.append(y)
        x_list2.append(x2)
        y_list2.append(y2)
    #print(len(x_list))
    im = ax1.plot(x_list,y_list,color='b',ls='solid', 
         marker='*',ms=18,markevery=slice(i-1,i,1))
    im2 = ax2.plot(x_list2,y_list2,color='r',ls='solid', 
         marker='*',ms=18,markevery=slice(i-1,i,1))
    ims.append(im+im2)

ani = animation.ArtistAnimation(fig,ims,interval=200)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">
