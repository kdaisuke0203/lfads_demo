# %% [markdown]
# # CAN Workshop- LFADS demo in pytorch

# %% [markdown]
# ## Import necessary modules

# %%
# %matplotlib inline

import torch
import torchvision
np = torch._np
import matplotlib.pyplot as plt

import os
import yaml
import math
from lfads_sim import LFADS_Net
from utils import read_data, load_parameters, save_parameters
import scipy.io
# plt.style.use('dark_background')
import shutil
path = './models_sim'
if os.path.isdir(path): 
    shutil.rmtree(path)

# %%
# Select device to train LFADS on
device = 'cuda' if torch.cuda.is_available() else 'cpu'; print('Using device: %s'%device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load or Generate Data

# %%
all_time =2500
start_time = 0
Time = 20
neuron_num = 30
datax = scipy.io.loadmat("spike30_sim_3000.mat")
y_data = datax["spike30_sim_3000"][start_time:all_time,:]
traj = scipy.io.loadmat("trj30_sim_3000.mat")
traj = traj["trj30_sim_3000"][start_time:all_time,:]
NRep=int((all_time-start_time)/Time)
output = np.zeros((NRep,Time,neuron_num))
print(y_data.shape)
#for i in range(all_time-start_time):
#    for j in range(neuron_num):
#        if y_data[i][j] > 20:
#            y_data[i][j] = 20
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
output = output.astype('float32')
output = torch.Tensor(output).to(device)
print(output.shape)
output_valid = output.detach().clone()
# Out:
# (2500, 30)
# torch.Size([125, 20, 30])

# %% [markdown]
# ## View example Ground Truth Firing Rates

# %%
train_ds      = torch.utils.data.TensorDataset(output)
valid_ds      = torch.utils.data.TensorDataset(output)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
plt.figure(figsize = (12,12))
plt.imshow(y_data.T, cmap=plt.cm.plasma,aspect='auto')
plt.xlabel('Time (s)')
plt.ylabel('Cell #')
plt.colorbar(orientation='horizontal', label='Firing Rate (Hz)')
# Out:
# (20, 30)

# %%
#for i in range(neuron_num):
    #fig, ax = plt.subplots()
    #mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=8)
    #fig.colorbar(mappable)
    #plt.title(i)
    #plt.show()
#fig.savefig("img.png")

# %% [markdown]
# ## LFADS Schema
# <img src='lfads_schema.png' width=800 align=left>

# %% [markdown]
# ## Load model hyperparameters

# %%
hyperparams = load_parameters('./parameters_sim.yaml')
save_parameters(hyperparams)
hyperparams
# Out:
# {'dataset_name': 'chaotic_rnn',
#  'run_name': 'demo',
#  'g_dim': 30,
#  'u_dim': 30,
#  'factors_dim': 2,
#  'g0_encoder_dim': 30,
#  'c_encoder_dim': 30,
#  'controller_dim': 30,
#  'g0_prior_kappa': 0.1,
#  'u_prior_kappa': 0.1,
#  'keep_prob': 0.95,
#  'clip_val': 5.0,
#  'max_norm': 200,
#  'learning_rate': 0.01,
#  'learning_rate_min': 1e-05,
#  'learning_rate_decay': 0.9,
#  'scheduler_on': True,
#  'scheduler_patience': 6,
#  'scheduler_cooldown': 6,
#  'kl_weight_schedule_start': 0,
#  'kl_weight_schedule_dur': 2000,
#  'l2_weight_schedule_start': 0,
#  'l2_weight_schedule_dur': 2000,
#  'epsilon': 0.1,
#  'betas': (0.9, 0.99),
#  'l2_gen_scale': 2000,
#  'l2_con_scale': 0}

# %% [markdown]
# ## Instantiate LFADS model

# %%
model = LFADS_Net(inputs_dim = neuron_num, T = Time, dt = 1, device=device,
                 model_hyperparams=hyperparams).to(device)
# Out:
# Random seed: 3182

# %% [markdown]
# #### Pick up where you left off (if you have a recent save)

# %%
# model.load_checkpoint('recent')
batch_size = 2
"""tt = np.empty((3000,2))
for k in range(10):
    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(t[90].shape)
    for i in range(batch_size):
        for j in range(100):
            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()
plt.figure()
plt.plot(tt)"""
# Out:
# "tt = np.empty((3000,2))\nfor k in range(10):\n    t = model.infer_trj(output_valid[batch_size *k:batch_size *(k+1),:])\n    #print(t[90].shape)\n    for i in range(batch_size):\n        for j in range(100):\n            tt[k*100*i+j,:]=t[j][i].to('cpu').detach().numpy().copy()\nplt.figure()\nplt.plot(tt)"

# %% [markdown]
# ## Fit model
#
# Rule of thumb: You can usually see good fit after 200 epochs (~30 mins runtime on Thinkpad GPU, ~2.5 hours on CPU), but to see good inference of perturbation timings need to run for about 800 epochs (~2 hours on Thinkpad GPU).

# %%
model.fit(train_ds, valid_ds, max_epochs=100, batch_size=batch_size , use_tensorboard=False,
          train_truth=train_ds, valid_truth=valid_ds)
# Out:
# Beginning training...
# Epoch:    1, Step:    63, training loss: 551.752
# recon:  198, kl:    14, dir:    0, klf:    1, klw:    0
# Epoch:    2, Step:   126, training loss: 431.214
# recon:  240, kl:    17, dir:  253, klf:    2, klw:    0
# Epoch:    3, Step:   189, training loss: 376.934
# recon:  288, kl:    19, dir: 2533, klf:    6, klw:    0
# Epoch:    4, Step:   252, training loss: 341.585
# recon:  390, kl:    19, dir:  232, klf:    3, klw:    0
# Epoch:    5, Step:   315, training loss: 328.704
# recon:  303, kl:    11, dir:  368, klf:    7, klw:    0
# Epoch:    6, Step:   378, training loss: 323.365
# recon:  117, kl:    14, dir:    2, klf:    3, klw:    0
# Epoch:    7, Step:   441, training loss: 317.316
# recon:  175, kl:    21, dir:  884, klf:    7, klw:    0
# Epoch:    8, Step:   504, training loss: 323.219
# recon:  202, kl:    26, dir:  250, klf:    4, klw:    0
# Epoch:    9, Step:   567, training loss: 305.127
# recon:  364, kl:    34, dir:  226, klf:   11, klw:    0
# Epoch:   10, Step:   630, training loss: 306.195
# recon:  263, kl:    24, dir: 2571, klf:   10, klw:    0
# Epoch:   11, Step:   693, training loss: 318.637
# recon:  298, kl:    20, dir:  217, klf:    5, klw:    0
# Epoch:   12, Step:   756, training loss: 304.859
# recon:  194, kl:    21, dir:  249, klf:   11, klw:    0
# Epoch:   13, Step:   819, training loss: 312.513
# recon:  235, kl:    15, dir: 1002, klf:    4, klw:    0
# Epoch:   14, Step:   882, training loss: 296.430
# recon:  203, kl:    13, dir: 1508, klf:    5, klw:    0
# Epoch:   15, Step:   945, training loss: 301.115
# recon:  282, kl:    19, dir: 2005, klf:    6, klw:    0
# Epoch:   16, Step:  1008, training loss: 309.330
# recon:  199, kl:    11, dir: 2234, klf:    5, klw:    0
# Epoch:   17, Step:  1071, training loss: 312.216
# recon:  396, kl:    49, dir:  214, klf:   12, klw:    0
# Epoch:   18, Step:  1134, training loss: 306.876
# recon:  418, kl:    39, dir:  234, klf:   18, klw:    0
# Epoch:   19, Step:  1197, training loss: 298.649
# recon:  373, kl:    43, dir:  219, klf:   16, klw:    0
# Epoch:   20, Step:  1260, training loss: 292.542
# recon:  192, kl:    14, dir:  691, klf:    6, klw:    0
# Epoch:   21, Step:  1323, training loss: 319.203
# recon:  515, kl:    41, dir:  498, klf:   19, klw:    0
# Learning rate decreased to 0.00900000
# Epoch:   22, Step:  1386, training loss: 321.293
# recon:  511, kl:    50, dir:  503, klf:   23, klw:    0
# Epoch:   23, Step:  1449, training loss: 309.044
# recon:  229, kl:    40, dir:   33, klf:   17, klw:    0
# Epoch:   24, Step:  1512, training loss: 299.221
# recon:  145, kl:    17, dir:    5, klf:    7, klw:    0
# Epoch:   25, Step:  1575, training loss: 295.046
# recon:  450, kl:    45, dir: 1266, klf:   30, klw:    0
# Epoch:   26, Step:  1638, training loss: 302.350
# recon:  201, kl:     8, dir: 3819, klf:    6, klw:    0
# Epoch:   27, Step:  1701, training loss: 303.457
# recon:  210, kl:     9, dir: 1484, klf:    5, klw:    0
# Epoch:   28, Step:  1764, training loss: 302.920
# recon:  753, kl:   114, dir: 1137, klf:   35, klw:    0
# Epoch:   29, Step:  1827, training loss: 297.158
# recon:   53, kl:    17, dir:    0, klf:    7, klw:    0
# Epoch:   30, Step:  1890, training loss: 316.959
# recon:  125, kl:    14, dir:   13, klf:   11, klw:    0
# Learning rate decreased to 0.00810000
# Epoch:   31, Step:  1953, training loss: 295.136
# recon:   99, kl:    16, dir:  108, klf:   11, klw:    0
# Epoch:   32, Step:  2016, training loss: 302.126
# recon:  189, kl:    20, dir: 1167, klf:   17, klw:    1
# Epoch:   33, Step:  2079, training loss: 290.127
# recon:  294, kl:    23, dir:   90, klf:   12, klw:    1
# Epoch:   34, Step:  2142, training loss: 299.430
# recon:  435, kl:    10, dir:  232, klf:    7, klw:    1
# Epoch:   35, Step:  2205, training loss: 298.053
# recon:  193, kl:    43, dir:   33, klf:   21, klw:    1
# Epoch:   36, Step:  2268, training loss: 282.116
# recon:  222, kl:     7, dir: 1846, klf:    5, klw:    1
# Epoch:   37, Step:  2331, training loss: 283.766
# recon:  217, kl:    30, dir:  569, klf:   16, klw:    1
# Epoch:   38, Step:  2394, training loss: 294.541
# recon:  356, kl:    44, dir:  392, klf:   22, klw:    1
# Epoch:   39, Step:  2457, training loss: 288.633
# recon:  124, kl:    12, dir:    1, klf:    8, klw:    1
# Epoch:   40, Step:  2520, training loss: 292.592
# recon:  269, kl:    29, dir:   72, klf:   13, klw:    1
# Epoch:   41, Step:  2583, training loss: 283.432
# recon:  191, kl:    30, dir:  516, klf:   12, klw:    1
# Epoch:   42, Step:  2646, training loss: 288.727
# recon:   86, kl:    10, dir:    0, klf:    6, klw:    1
# Epoch:   43, Step:  2709, training loss: 289.713
# recon:  448, kl:    41, dir:   81, klf:   25, klw:    1
# Epoch:   44, Step:  2772, training loss: 286.781
# recon:  188, kl:    24, dir: 1706, klf:   17, klw:    1
# Epoch:   45, Step:  2835, training loss: 291.893
# recon:  293, kl:    39, dir:  415, klf:   37, klw:    1
# Epoch:   46, Step:  2898, training loss: 280.953
# recon:  205, kl:    38, dir:  828, klf:   11, klw:    1
# Epoch:   47, Step:  2961, training loss: 281.681
# recon:  287, kl:    56, dir:  108, klf:   19, klw:    1
# Epoch:   48, Step:  3024, training loss: 283.268
# recon:  215, kl:    18, dir:  161, klf:   17, klw:    1
# Epoch:   49, Step:  3087, training loss: 287.808
# recon:  133, kl:     9, dir:   23, klf:   10, klw:    1
# Epoch:   50, Step:  3150, training loss: 280.179
# recon:  111, kl:    24, dir:   12, klf:    7, klw:    1
# Epoch:   51, Step:  3213, training loss: 280.851
# recon:   70, kl:    12, dir:    0, klf:    6, klw:    1
# Epoch:   52, Step:  3276, training loss: 279.659
# recon:  256, kl:    15, dir: 1250, klf:    9, klw:    1
# Epoch:   53, Step:  3339, training loss: 279.057
# recon:  259, kl:    47, dir:  158, klf:   21, klw:    1
# Epoch:   54, Step:  3402, training loss: 268.545
# recon:  101, kl:    14, dir:    3, klf:   13, klw:    1
# Epoch:   55, Step:  3465, training loss: 270.754
# recon:  240, kl:    40, dir:  183, klf:   17, klw:    1
# Epoch:   56, Step:  3528, training loss: 284.322
# recon:  119, kl:    23, dir:    8, klf:    8, klw:    1
# Learning rate decreased to 0.00729000
# Epoch:   57, Step:  3591, training loss: 292.355
# recon:  369, kl:    54, dir:  209, klf:   31, klw:    1
# Epoch:   58, Step:  3654, training loss: 263.505
# recon:  100, kl:    14, dir:    1, klf:    6, klw:    1
# Epoch:   59, Step:  3717, training loss: 273.150
# recon:   81, kl:     8, dir:  156, klf:    9, klw:    1
# Epoch:   60, Step:  3780, training loss: 276.260
# recon:  201, kl:    14, dir: 1077, klf:    3, klw:    1
# Epoch:   61, Step:  3843, training loss: 270.184
# recon:  116, kl:    23, dir:    9, klf:    7, klw:    1
# Epoch:   62, Step:  3906, training loss: 269.068
# recon:  255, kl:    40, dir:  151, klf:   22, klw:    1
# Epoch:   63, Step:  3969, training loss: 268.749
# recon:  102, kl:    11, dir:    3, klf:    8, klw:    1
# Epoch:   64, Step:  4032, training loss: 270.846
# recon:  500, kl:    84, dir:  604, klf:   22, klw:    1
# Epoch:   65, Step:  4095, training loss: 266.285
# recon:  108, kl:    10, dir:   13, klf:    9, klw:    1
# Epoch:   66, Step:  4158, training loss: 276.960
# recon:  233, kl:     8, dir:  451, klf:    4, klw:    1
# Learning rate decreased to 0.00656100
# Epoch:   67, Step:  4221, training loss: 274.671
# recon:  268, kl:    50, dir:  276, klf:   24, klw:    1
# Epoch:   68, Step:  4284, training loss: 266.045
# recon:  198, kl:     6, dir: 16419, klf:    6, klw:    1
# Epoch:   69, Step:  4347, training loss: 271.724
# recon:  366, kl:    36, dir: 3284, klf:   31, klw:    1
# Epoch:   70, Step:  4410, training loss: 265.358
# recon:  220, kl:    25, dir:  275, klf:   15, klw:    1
# Epoch:   71, Step:  4473, training loss: 274.842
# recon:  261, kl:     8, dir: 2481, klf:    5, klw:    1
# Epoch:   72, Step:  4536, training loss: 272.668
# recon:  199, kl:     6, dir: 1141, klf:    5, klw:    1
# Epoch:   73, Step:  4599, training loss: 261.241
# recon:  207, kl:     7, dir: 1219, klf:    4, klw:    1
# Epoch:   74, Step:  4662, training loss: 264.990
# recon:   71, kl:    10, dir:    1, klf:    9, klw:    1
# Epoch:   75, Step:  4725, training loss: 279.037
# recon:  402, kl:    58, dir:  349, klf:   23, klw:    1
# Learning rate decreased to 0.00590490
# Epoch:   76, Step:  4788, training loss: 248.580
# recon:  171, kl:    18, dir:  756, klf:    9, klw:    1
# Epoch:   77, Step:  4851, training loss: 263.968
# recon:  279, kl:    17, dir:  119, klf:   10, klw:    1
# Epoch:   78, Step:  4914, training loss: 265.913
# recon:  395, kl:    33, dir:  141, klf:   23, klw:    1
# Epoch:   79, Step:  4977, training loss: 256.090
# recon:  394, kl:    32, dir:  250, klf:   19, klw:    1
# Epoch:   80, Step:  5040, training loss: 248.259
# recon:  121, kl:    11, dir:    2, klf:    5, klw:    1
# Epoch:   81, Step:  5103, training loss: 263.896
# recon:  199, kl:     8, dir: 3173, klf:    7, klw:    1
# Epoch:   82, Step:  5166, training loss: 256.427
# recon:  131, kl:    15, dir:  592, klf:    7, klw:    1
# Epoch:   83, Step:  5229, training loss: 259.421
# recon:   96, kl:    10, dir:    3, klf:    6, klw:    1
# Epoch:   84, Step:  5292, training loss: 258.791
# recon:   87, kl:    13, dir:    1, klf:   10, klw:    1
# Epoch:   85, Step:  5355, training loss: 254.005
# recon:  207, kl:    49, dir: 1515, klf:   21, klw:    1
# Epoch:   86, Step:  5418, training loss: 259.892
# recon:  207, kl:     5, dir: 1405, klf:    6, klw:    1
# Epoch:   87, Step:  5481, training loss: 255.151
# recon:  295, kl:     3, dir:  687, klf:    7, klw:    1
# Epoch:   88, Step:  5544, training loss: 258.201
# recon:  119, kl:     8, dir:    1, klf:    8, klw:    1
# Epoch:   89, Step:  5607, training loss: 253.245
# recon:  113, kl:    11, dir:    0, klf:    6, klw:    1
# Epoch:   90, Step:  5670, training loss: 252.062
# recon:  258, kl:    45, dir:  103, klf:   23, klw:    1
# Epoch:   91, Step:  5733, training loss: 260.310
# recon:  348, kl:     9, dir: 1326, klf:    8, klw:    1
# Learning rate decreased to 0.00531441
# Epoch:   92, Step:  5796, training loss: 254.966
# recon:  199, kl:     4, dir: 1048, klf:    6, klw:    1
# Epoch:   93, Step:  5859, training loss: 250.927
# recon:  251, kl:     4, dir:  389, klf:    2, klw:    1
# Epoch:   94, Step:  5922, training loss: 253.080
# recon:  219, kl:     6, dir: 4736, klf:    4, klw:    1
# Epoch:   95, Step:  5985, training loss: 256.023
# recon:   90, kl:    22, dir:   16, klf:    8, klw:    1
# Epoch:   96, Step:  6048, training loss: 256.160
# recon:  367, kl:     8, dir: 2300, klf:    4, klw:    1
# Epoch:   97, Step:  6111, training loss: 256.472
# recon:  226, kl:     5, dir: 1131, klf:    3, klw:    1
# Epoch:   98, Step:  6174, training loss: 250.624
# recon:  415, kl:    60, dir:  817, klf:   27, klw:    1
# Epoch:   99, Step:  6237, training loss: 251.205
# recon:  216, kl:    30, dir:  651, klf:    8, klw:    1
# Epoch:  100, Step:  6300, training loss: 248.621
# recon:   82, kl:     8, dir:    0, klf:    5, klw:    1
# ...training complete.

# %% [markdown]
# ## Load checkpoint with lowest validation error

# %%
print(output_valid.shape)
#model.plot_factors()
tt = np.zeros(((all_time-start_time),2))
sp = np.zeros(((all_time-start_time),neuron_num))
batch_size=1
gg = int(NRep/batch_size)
import math
def mutual_info(m):
    K=30
    h_y_xw = np.zeros(neuron_num)
    h_y_x = np.zeros(neuron_num)
    T = m.shape[0]
    for n in range(neuron_num):
        for k in range(K):
            h_y_xw_tem = 0
            h_y_x_tem = 0
            for t in range(T):
                h_y_xw_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)) * np.log(m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k)))
                h_y_x_tem += m[t][n]**(k)*np.exp(-m[t][n])/(math.factorial(k))
            h_y_xw[n] += h_y_xw_tem/T
            h_y_x[n] -= h_y_x_tem/T * math.log(h_y_x_tem/T)
            
    return  h_y_xw, h_y_x

for k in range(gg):
    t = model.infer_factors(output_valid[batch_size *k:batch_size *(k+1),:])
    #spi = model.reconstruct(output_valid[batch_size *k:batch_size *(k+1),:])
    #print(spi.shape)
    for i in range(batch_size):
        for j in range(Time):
            tt[(i+batch_size*k)*Time+j,:] = t[i][j].to('cpu').detach().numpy().copy()
            #print(model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10))
            #y_hat = model.mcdropout(output_valid[batch_size *k:batch_size *(k+1),:],np.ones(2),T=10)
            #print(mutual_info(y_hat))
            #obs_mc_mean = y_hat.mean(axis=0)
            #obs_mc_std = y_hat.std(axis=0)
            #print(poisson_entropy(np.round(obs_mc_mean)))
            #for l in range(neuron_num):
                #sp[(i+batch_size*k)*Time+j,l] = spi[j][l]
plt.figure()
plt.plot(tt)
# Out:
# torch.Size([125, 20, 30])
# [<matplotlib.lines.Line2D at 0x1cf40aa1550>,
#  <matplotlib.lines.Line2D at 0x1cf40aa16a0>]

# %% [markdown]
# ## Plot results summary

# %%
# for i in range(neuron_num):
    plt.figure()
    plt.plot(y_data[:,i], linewidth = 2)
    plt.plot(sp[:,i],'r',linewidth = 1)
    plt.title(i)
    plt.ylim(-2,20)
# Out:
# (-2, 20)

# %%
import funs
qz_mean_est = tt
plt.plot(qz_mean_est[:,1])
qz_est_norm = qz_mean_est#np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
#plt.plot(qz_est_norm[:,0],qz_est_norm[:,1])
z_true_c = traj# - x_test.mean(axis=0)
z_true_norm = z_true_c#/np.linalg.norm(z_true_c)

R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
plt.figure(figsize=(14,8))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure(figsize=(5,5))
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')

# %%
#np.savetxt('lfads_k09_sim_12301628.csv', qz_est_norm_R, delimiter=',')
